# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.ndimage import gaussian_filter1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# ==========================================
# [실험 설정 구간] 모든 하이퍼파라미터 통합 
# ==========================================
DATA_PATH = './CMAPSSData/'
CONFIG = {
    'DATA_ID': 'FD001',
    'RUL_CAP': 125,
    'GAUSS_SIGMA': 2,
    'RANDOM_STATE': 42,
    'TEST_SIZE': 0.2,
    'SCALER_TYPE': 'minmax',  # minmax , Standard
    
    # 사용할 센서 직접 지정 (상수 센서 자동 감지 대신 사용)
    'BASE_SENSORS': ['s_2', 's_3', 's_4', 's_7', 's_8', 's_9', 's_11', 
                     's_12', 's_13', 's_14', 's_15', 's_17', 's_20', 's_21'],
    'SETTING_FEATURES': ['setting_1', 'setting_2', 'setting_3'],

    # 파생변수 설정 (리스트 형식 지원)
    'USE_MA': True,   'WIN_MA': [5],
    'USE_STD': True,  'WIN_STD': [10],  
    'USE_DIFF': True, 'PER_DIFF': [1],
    'USE_EMA': True,  'SPAN_EMA': [10],
    'USE_LAG': True,  'LAG_STEP': [10],
}

# ---------------------------------------------------------
# [1] 데이터 로드 및 초기 전처리 (Capping & 상수 제거)
# ---------------------------------------------------------
def load_and_basic_prep(config):
    # 전체 컬럼 정의
    cols = ['unit_nr', 'time_cycles', 'setting_1', 'setting_2', 'setting_3'] + [f's_{i}' for i in range(1, 22)]
    
    # 데이터 로드
    train = pd.read_csv(f"{DATA_PATH}train_{config['DATA_ID']}.txt", sep='\s+', header=None, names=cols)
    test = pd.read_csv(f"{DATA_PATH}test_{config['DATA_ID']}.txt", sep='\s+', header=None, names=cols)
    y_test_final = pd.read_csv(f"{DATA_PATH}RUL_{config['DATA_ID']}.txt", sep='\s+', header=None, names=['RUL'])['RUL'].values

    # RUL 생성 및 Capping
    train['max_cycle'] = train.groupby('unit_nr')['time_cycles'].transform('max')
    train['RUL'] = (train['max_cycle'] - train['time_cycles']).clip(upper=config['RUL_CAP'])
    train.drop(columns=['max_cycle'], inplace=True)

    # 명시적으로 선택한 컬럼만 유지 (unit_nr, time_cycles, RUL + 선택 센서 + 세팅값)
    keep_cols = ['unit_nr', 'time_cycles'] + config['SETTING_FEATURES'] + config['BASE_SENSORS']
    
    # Train은 RUL 포함, Test는 RUL 제외하고 선택
    train = train[keep_cols + ['RUL']]
    test = test[keep_cols]
    
    print(f" 센서 선택 완료: {config['BASE_SENSORS']}")
    print(f" 유지된 컬럼 총 {len(train.columns)}개 (RUL 포함)")
    
    return train, test, y_test_final

# 실행 
df_train, df_test, y_test = load_and_basic_prep(CONFIG)

# ---------------------------------------------------------
# [2] 가우시안 스무딩 (Team Style)
# ---------------------------------------------------------
def apply_gaussian_smoothing(df, sigma):
    if sigma <= 0: return df.copy()
    df = df.copy().sort_values(['unit_nr', 'time_cycles']).reset_index(drop=True)
    sensors = [c for c in df.columns if c.startswith('s_')]
    
    for uid in df['unit_nr'].unique():
        mask = df['unit_nr'] == uid
        for col in sensors:
            arr = df.loc[mask, col].to_numpy(dtype=np.float32)
            df.loc[mask, col] = gaussian_filter1d(arr, sigma=sigma, mode='nearest')
    return df

df_train = apply_gaussian_smoothing(df_train, CONFIG['GAUSS_SIGMA'])
df_test = apply_gaussian_smoothing(df_test, CONFIG['GAUSS_SIGMA'])
print(f"✅ 가우시안 스무딩 완료 (Sigma: {CONFIG['GAUSS_SIGMA']})")

# ---------------------------------------------------------
# [3] 데이터 분할 (Train / Val)
# ---------------------------------------------------------
unit_ids = df_train['unit_nr'].unique()
train_units, val_units = train_test_split(unit_ids, test_size=CONFIG['TEST_SIZE'], random_state=CONFIG['RANDOM_STATE'])

train_set = df_train[df_train['unit_nr'].isin(train_units)].copy()
val_set = df_train[df_train['unit_nr'].isin(val_units)].copy()
test_set = df_test.copy()

# ---------------------------------------------------------
# [4] 정규화 (Base Sensors + Settings)
# ---------------------------------------------------------
base_sensors = sorted([c for c in df_train.columns if c.startswith('s_')], key=lambda x: int(x.split('_')[1]))
base_plus_setting = base_sensors + CONFIG['SETTING_FEATURES']

if CONFIG['SCALER_TYPE'] == 'minmax':
    scaler = MinMaxScaler()
else:
    scaler = StandardScaler()

train_set[base_plus_setting] = scaler.fit_transform(train_set[base_plus_setting])
val_set[base_plus_setting] = scaler.transform(val_set[base_plus_setting])
test_set[base_plus_setting] = scaler.transform(test_set[base_plus_setting])
print(f" 정규화 완료 ({CONFIG['SCALER_TYPE']})")

# ---------------------------------------------------------
# [5] 파생변수 생성 (다중 윈도우 지원 수정 버전)
# ---------------------------------------------------------
def add_features_final(df, features, config):
    df_res = df.copy()
    for col in features:
        group = df_res.groupby('unit_nr')[col]

        if config['USE_MA']:
            wins = config['WIN_MA'] if isinstance(config['WIN_MA'], list) else [config['WIN_MA']]
            for w in wins:
                df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
        
        if config['USE_STD']:
            wins = config['WIN_STD'] if isinstance(config['WIN_STD'], list) else [config['WIN_STD']]
            for w in wins:
                df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
            
        if config['USE_DIFF']:
            pers = config['PER_DIFF'] if isinstance(config['PER_DIFF'], list) else [config['PER_DIFF']]
            for p in pers:
                df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
            
        if config['USE_EMA']:
            spans = config['SPAN_EMA'] if isinstance(config['SPAN_EMA'], list) else [config['SPAN_EMA']]
            for s in spans:
                df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
            
        if config['USE_LAG']:
            steps = config['LAG_STEP'] if isinstance(config['LAG_STEP'], list) else [config['LAG_STEP']]
            for st in steps:
                df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
                
    return df_res

train_set = add_features_final(train_set, base_sensors, CONFIG)
val_set = add_features_final(val_set, base_sensors, CONFIG)
test_set = add_features_final(test_set, base_sensors, CONFIG)

# 최종 피처 리스트 구성 (다중 윈도우 컬럼명 자동 반영)
X_features_full = base_sensors + CONFIG['SETTING_FEATURES']
def get_derived_colnames(base_sensors, config, prefix, config_key):
    if not config[prefix]: return []
    vals = config[config_key] if isinstance(config[config_key], list) else [config[config_key]]
    suffix = 'ma' if config_key == 'WIN_MA' else 'std' if config_key == 'WIN_STD' else 'diff' if config_key == 'PER_DIFF' else 'ema' if config_key == 'SPAN_EMA' else 'lag'
    return [f'{c}_{suffix}{v}' for c in base_sensors for v in vals]

X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_MA', 'WIN_MA')
X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_STD', 'WIN_STD')
X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_DIFF', 'PER_DIFF')
X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_EMA', 'SPAN_EMA')
X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_LAG', 'LAG_STEP')

# 최종 변수 할당
X_train, y_train = train_set[X_features_full], train_set['RUL']
X_val, y_val = val_set[X_features_full], val_set['RUL']
X_test = test_set.groupby('unit_nr').last()[X_features_full]

print(f"\n 전처리 파이프라인 완료")
print(f" 최종 피처 수: {len(X_features_full)}개")
print(f" X_train: {X_train.shape}, X_val: {X_val.shape}, X_test: {X_test.shape}")
print(f" y_train: {y_train.shape}, y_val: {y_val.shape}, y_test: {y_test.shape}")
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:44: SyntaxWarning: invalid escape sequence '\s'
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:44: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\skrke\AppData\Local\Temp\ipykernel_22712\3302091580.py:42: SyntaxWarning: invalid escape sequence '\s'
#   train = pd.read_csv(f"{DATA_PATH}train_{config['DATA_ID']}.txt", sep='\s+', header=None, names=cols)
# C:\Users\skrke\AppData\Local\Temp\ipykernel_22712\3302091580.py:43: SyntaxWarning: invalid escape sequence '\s'
#   test = pd.read_csv(f"{DATA_PATH}test_{config['DATA_ID']}.txt", sep='\s+', header=None, names=cols)
# C:\Users\skrke\AppData\Local\Temp\ipykernel_22712\3302091580.py:44: SyntaxWarning: invalid escape sequence '\s'
#   y_test_final = pd.read_csv(f"{DATA_PATH}RUL_{config['DATA_ID']}.txt", sep='\s+', header=None, names=['RUL'])['RUL'].values
#  센서 선택 완료: ['s_2', 's_3', 's_4', 's_7', 's_8', 's_9', 's_11', 's_12', 's_13', 's_14', 's_15', 's_17', 's_20', 's_21']
#  유지된 컬럼 총 20개 (RUL 포함)
# C:\Users\skrke\AppData\Local\Temp\ipykernel_22712\3302091580.py:78: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[391.77582 391.68353 391.64896 391.67813 391.7251  391.75134 391.7735
#  391.8313  391.92657 392.0214  392.08725 392.12457 392.1319  392.09442
#  392.01413 391.9201  391.84152 391.7934  391.78723 391.8313  391.92325
#  392.05826 392.23425 392.42435 392.55026 392.51938 392.3118  392.01746
#  391.77063 391.65387 391.65915 391.71765 391.76212 391.77487 391.7844
#  391.81982 391.87827 391.9356  391.97565 392.00223 392.03354 392.0913
#  392.18576 392.2974  392.3773  392.38205 392.31525 392.22345 392.14755
#  392.08847 392.02478 391.94785 391.86353 391.77057 391.66293 391.55713
#  391.49835 391.52277 391.61795 391.73416 391.83292 391.90213 391.93484
#  391.93262 391.92432 391.94    391.96414 391.94235 391.83783 391.67056
#  391.50626 391.41058 391.4072  391.47897 391.6106  391.80786 392.05795
#  392.2931  392.42627 392.42255 392.32175 392.20245 392.13412 392.13864
#  392.17502 392.17664 392.1243  392.071   392.08588 392.1859  392.33176
#  392.4755  392.58728 392.63516 392.5806  392.4256  392.23752 392.09656
#  392.0326  392.03033 392.0741  392.1651  392.316   392.54474 392.8514
#  393.18127 393.42896 393.511   393.4394  393.31396 393.23843 393.2431
#  393.27734 393.2664  393.1794  393.06015 392.9943  393.0301  393.12717
#  393.19363 393.1729  393.08734 393.00104 392.95306 392.93594 392.9309
#  392.93317 392.93524 392.919   392.8851  392.8663  392.8854  392.92142
#  392.9443  392.96127 392.99976 393.06482 393.13437 393.17975 393.18176
#  393.14938 393.12347 393.1365  393.16638 393.16107 393.11877 393.1142
#  393.22583 393.45062 393.70282 393.88705 393.96622 393.96765 393.93585
#  393.89435 393.86307 393.88608 393.9952  394.1443  394.22467 394.1671
#  394.0107  393.86157 393.7977  393.81882 393.87604 393.93765 394.01343
#  394.11014 394.19003 394.20236 394.1476  394.09036 394.1142  394.2661
#  394.5264  394.82907 395.12427 395.41025 395.68817 395.90732 395.9982
#  395.96176 395.8879  395.86697 395.9072  395.9553  395.96823 395.94012
#  395.88693 395.83826 395.82684]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[mask, col] = gaussian_filter1d(arr, sigma=sigma, mode='nearest')
# C:\Users\skrke\AppData\Local\Temp\ipykernel_22712\3302091580.py:78: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[392.17642 392.11795 391.93655 391.69623 391.5161  391.4609  391.48407
#  391.48898 391.43274 391.35953 391.34018 391.39062 391.45013 391.43777
#  391.3329  391.20142 391.14267 391.21512 391.411   391.68246 391.9737
#  392.22977 392.39252 392.4173  392.3117  392.1463  392.01035 391.9618
#  392.0214  392.1852  392.41766]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[mask, col] = gaussian_filter1d(arr, sigma=sigma, mode='nearest')
# ✅ 가우시안 스무딩 완료 (Sigma: 2)
#  정규화 완료 (minmax)
#
#  전처리 파이프라인 완료
#  최종 피처 수: 87개
#  X_train: (16561, 87), X_val: (4070, 87), X_test: (100, 87)
#  y_train: (16561,), y_val: (4070,), y_test: (100,)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

def calculate_nasa_score(y_true, y_pred):
    """C-MAPSS 전용 NASA Score 계산 함수 ㅋ"""
    diff = y_pred - y_true
    # 조기 예측(diff < 0)보다 늦은 예측(diff > 0)에 더 큰 패널티 부여 
    score = np.where(diff < 0, np.exp(-diff/13)-1, np.exp(diff/10)-1)
    return np.sum(score)

def evaluate_model(y_true, y_pred, model_name):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    score = calculate_nasa_score(y_true, y_pred)
    print(f"[{model_name}] 평가 결과")
    print(f" RMSE: {rmse:.4f}")
    print(f" NASA Score: {score:.4f}")
    return rmse, score

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import time
import optuna
from optuna.samplers import TPESampler
import xgboost as xgb
import lightgbm as lgb

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

def report_performance(y_true, y_pred, model_name):
    """
    예측 결과를 평가하고 시각화하는 공통 함수
    """
    # 1. 지표 계산 (RMSE)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    
    # 2. NASA Score 계산 (비대칭 페널티)
    # 실제보다 늦게 예측할 때(Overestimation) 더 큰 페널티를 부여하는 방식
    d = y_pred - y_true
    nasa_score = np.sum(np.where(d < 0, np.exp(-d/13)-1, np.exp(d/10)-1))
    
    print(f"\n{'='*55}")
    print(f" [{model_name}] 모델 평가 결과")
    print(f"{'-'*55}")
    print(f" RMSE       : {rmse:.4f}")
    print(f" NASA Score : {nasa_score:.4f}")
    print(f"{'='*55}")
    
    # 3. 트렌드 시각화
    plt.figure(figsize=(15, 5))
    
    # 데이터가 너무 많으면 가독성을 위해 앞부분 일부만 출력
    display_step = min(100, len(y_true)) 
    
    plt.plot(y_true[:display_step], label='Actual RUL', color='black', linestyle='--', alpha=0.7, marker='o', markersize=4)
    plt.plot(y_pred[:display_step], label=f'Predicted (by {model_name})', color='crimson', linewidth=2, marker='x', markersize=4)
    
    # 오차 범위 시각화
    plt.fill_between(range(display_step), y_true[:display_step], y_pred[:display_step], color='crimson', alpha=0.1)
    
    plt.title(f'RUL Prediction Trend: {model_name}', fontsize=14, fontweight='bold')
    plt.xlabel('Test Unit Sample Index (Subset)')
    plt.ylabel('Remaining Useful Life (Cycles)')
    plt.legend(loc='upper right')
    plt.grid(True, linestyle=':', alpha=0.6)
    
    plt.tight_layout()
    plt.show()
    
    return rmse, nasa_score

# %%
# [사전 설정] 전처리 결과 연결
# FEATURES_LINEAR와 FEATURES_TREE를 동일하게 X_features_full로 사용하거나 
# 필요시 분리해서 정의
FEATURES_LINEAR = X_features_full 
FEATURES_TREE = X_features_full

# 하이퍼파라미터
N_TRIALS_LIN = 15
N_TRIALS_TRE = 30 

# ---------------------------------------------------------
# 4. 선형 모델 학습 (Optuna)
# ---------------------------------------------------------
print(f'=== 4. 선형 모델 학습 (Optuna) ===')
print(f'피처 수: {len(FEATURES_LINEAR)}개 | Trials: {N_TRIALS_LIN}\n')

def get_linear_model(trial, name):
    if name == 'Ridge':
        return Ridge(alpha=trial.suggest_float('alpha', 0.01, 500, log=True), 
                     random_state=CONFIG['RANDOM_STATE'])
    elif name == 'Lasso':
        return Lasso(alpha=trial.suggest_float('alpha', 1e-4, 10, log=True), 
                     max_iter=10000, random_state=CONFIG['RANDOM_STATE'])
    else:  # ElasticNet
        return ElasticNet(
            alpha=trial.suggest_float('alpha', 1e-4, 10, log=True),
            l1_ratio=trial.suggest_float('l1_ratio', 0.05, 0.95),
            max_iter=10000, random_state=CONFIG['RANDOM_STATE'])

linear_models = ['Ridge', 'Lasso', 'ElasticNet']
linear_results = {}

for mname in linear_models:
    t0 = time.time()
    print(f'  [{mname}] Optuna 최적화 중... ', end='', flush=True)

    def objective(trial):
        model = get_linear_model(trial, mname)
        model.fit(X_train[FEATURES_LINEAR], y_train)
        # 검증셋(X_val) 기준으로 점수 최적화 ㅋ
        preds = model.predict(X_val[FEATURES_LINEAR])
        return np.sqrt(mean_squared_error(y_val, preds))

    study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=CONFIG['RANDOM_STATE']))
    study.optimize(objective, n_trials=N_TRIALS_LIN)

    # 최적 파라미터로 최종 학습
    best_p = study.best_params
    best_m = get_linear_model(optuna.trial.FixedTrial(best_p), mname)
    best_m.fit(X_train[FEATURES_LINEAR], y_train)

    # 평가
    rmse, score = report_performance(y_test, best_m.predict(X_test[FEATURES_LINEAR]), f"{mname} (Optuna)")
    linear_results[mname] = {'rmse': rmse, 'score': score, 'time': time.time()-t0}

# ---------------------------------------------------------
# 5. 트리 모델 학습 (Optuna)
# ---------------------------------------------------------
print(f'\n=== 5. 트리 모델 학습 (Optuna) ===')
print(f'피처 수: {len(FEATURES_TREE)}개 | Trials: {N_TRIALS_TRE}\n')

def get_tree_model(trial, name):
    if name == 'RandomForest':
        return RandomForestRegressor(
            n_estimators=trial.suggest_int('n_estimators', 100, 300),
            max_depth=trial.suggest_int('max_depth', 5, 30),
            min_samples_split=trial.suggest_int('min_samples_split', 2, 20),
            random_state=CONFIG['RANDOM_STATE'], n_jobs=-1)
    elif name == 'XGBoost':
        return xgb.XGBRegressor(
            n_estimators=trial.suggest_int('n_estimators', 100, 600),
            max_depth=trial.suggest_int('max_depth', 3, 10),
            learning_rate=trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            tree_method='hist', random_state=CONFIG['RANDOM_STATE'], n_jobs=-1, verbosity=0)
    else:  # LightGBM
        return lgb.LGBMRegressor(
            n_estimators=trial.suggest_int('n_estimators', 100, 600),
            max_depth=trial.suggest_int('max_depth', 3, 12),
            learning_rate=trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            num_leaves=trial.suggest_int('num_leaves', 20, 200),
            random_state=CONFIG['RANDOM_STATE'], n_jobs=-1, verbose=-1)

tree_models = ['RandomForest', 'XGBoost', 'LightGBM']
tree_results = {}

for mname in tree_models:
    t0 = time.time()
    print(f'  [{mname}] Optuna 최적화 중... ', end='', flush=True)

    def objective(trial):
        model = get_tree_model(trial, mname)
        model.fit(X_train[FEATURES_TREE], y_train)
        preds = model.predict(X_val[FEATURES_TREE])
        return np.sqrt(mean_squared_error(y_val, preds))

    study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=CONFIG['RANDOM_STATE']))
    study.optimize(objective, n_trials=N_TRIALS_TRE)

    # 최적 파라미터로 최종 학습
    best_p = study.best_params
    if mname == 'RandomForest':
        best_m = RandomForestRegressor(**best_p, random_state=CONFIG['RANDOM_STATE'], n_jobs=-1)
    elif mname == 'XGBoost':
        best_m = xgb.XGBRegressor(**best_p, tree_method='hist', random_state=CONFIG['RANDOM_STATE'], n_jobs=-1, verbosity=0)
    else:
        best_m = lgb.LGBMRegressor(**best_p, random_state=CONFIG['RANDOM_STATE'], n_jobs=-1, verbose=-1)
    
    best_m.fit(X_train[FEATURES_TREE], y_train)

    # 평가 및 시각화 ㅋ
    rmse, score = report_performance(y_test, best_m.predict(X_test[FEATURES_TREE]), f"{mname} (Optuna)")
    tree_results[mname] = {'rmse': rmse, 'score': score, 'time': time.time()-t0}
# Out:
# === 4. 선형 모델 학습 (Optuna) ===
# 피처 수: 87개 | Trials: 15
#
#   [Ridge] Optuna 최적화 중...
# [I 2026-04-24 14:26:12,565] A new study created in memory with name: no-name-92546f98-cb26-4742-8af3-b7112b0736a9
# [I 2026-04-24 14:26:12,591] Trial 0 finished with value: 16.8368318215332 and parameters: {'alpha': 0.575377379411719}. Best is trial 0 with value: 16.8368318215332.
# [I 2026-04-24 14:26:12,615] Trial 1 finished with value: 19.697374220230227 and parameters: {'alpha': 293.34453957883983}. Best is trial 0 with value: 16.8368318215332.
# [I 2026-04-24 14:26:12,637] Trial 2 finished with value: 17.75162200414357 and parameters: {'alpha': 27.518044962720857}. Best is trial 0 with value: 16.8368318215332.
# [I 2026-04-24 14:26:12,660] Trial 3 finished with value: 17.238125552929233 and parameters: {'alpha': 6.502468545951018}. Best is trial 0 with value: 16.8368318215332.
# [I 2026-04-24 14:26:12,684] Trial 4 finished with value: 16.29859454253716 and parameters: {'alpha': 0.05409123677836541}. Best is trial 4 with value: 16.29859454253716.
# [I 2026-04-24 14:26:12,708] Trial 5 finished with value: 16.29856390137304 and parameters: {'alpha': 0.054077122202881224}. Best is trial 5 with value: 16.29856390137304.
# [I 2026-04-24 14:26:12,730] Trial 6 finished with value: 16.226600876832606 and parameters: {'alpha': 0.01874705922180252}. Best is trial 6 with value: 16.226600876832606.
# [I 2026-04-24 14:26:12,752] Trial 7 finished with value: 18.920198660751318 and parameters: {'alpha': 117.52647960576222}. Best is trial 6 with value: 16.226600876832606.
# [I 2026-04-24 14:26:12,775] Trial 8 finished with value: 17.24319402558075 and parameters: {'alpha': 6.677615511747083}. Best is trial 6 with value: 16.226600876832606.
# [I 2026-04-24 14:26:12,797] Trial 9 finished with value: 17.612252894216276 and parameters: {'alpha': 21.242802137208894}. Best is trial 6 with value: 16.226600876832606.
# [I 2026-04-24 14:26:12,821] Trial 10 finished with value: 16.217019167545438 and parameters: {'alpha': 0.012487365959463722}. Best is trial 10 with value: 16.217019167545438.
# [I 2026-04-24 14:26:12,843] Trial 11 finished with value: 16.21406587897402 and parameters: {'alpha': 0.010202072983241583}. Best is trial 11 with value: 16.21406587897402.
# [I 2026-04-24 14:26:12,867] Trial 12 finished with value: 16.70302995638912 and parameters: {'alpha': 0.3430415094200433}. Best is trial 11 with value: 16.21406587897402.
# [I 2026-04-24 14:26:12,890] Trial 13 finished with value: 16.214533210727563 and parameters: {'alpha': 0.010581949937500931}. Best is trial 11 with value: 16.21406587897402.
# [I 2026-04-24 14:26:12,914] Trial 14 finished with value: 16.676278300541185 and parameters: {'alpha': 0.3110558839147533}. Best is trial 11 with value: 16.21406587897402.
# =======================================================
#  [Ridge (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 20.8780
#  NASA Score : 868.4709
# =======================================================
#   [Lasso] Optuna 최적화 중...
# [I 2026-04-24 14:26:13,026] A new study created in memory with name: no-name-59d79bf6-d5c4-49c7-8344-4c53a8dc4200
# [I 2026-04-24 14:27:29,792] Trial 0 finished with value: 17.235268130059257 and parameters: {'alpha': 0.0074593432857265485}. Best is trial 0 with value: 17.235268130059257.
# [I 2026-04-24 14:27:29,826] Trial 1 finished with value: 37.56381259428765 and parameters: {'alpha': 5.669849511478847}. Best is trial 0 with value: 17.235268130059257.
# [I 2026-04-24 14:27:33,390] Trial 2 finished with value: 20.446538985243443 and parameters: {'alpha': 0.4570563099801455}. Best is trial 0 with value: 17.235268130059257.
# [I 2026-04-24 14:27:42,599] Trial 3 finished with value: 18.59151108222793 and parameters: {'alpha': 0.09846738873614563}. Best is trial 0 with value: 17.235268130059257.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.070e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 14:31:03,717] Trial 4 finished with value: 16.774182968018486 and parameters: {'alpha': 0.0006026889128682511}. Best is trial 4 with value: 16.774182968018486.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.070e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 14:34:25,439] Trial 5 finished with value: 16.774212531695493 and parameters: {'alpha': 0.000602521573620386}. Best is trial 4 with value: 16.774182968018486.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.450e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 14:37:52,282] Trial 6 finished with value: 16.84579331061393 and parameters: {'alpha': 0.00019517224641449495}. Best is trial 4 with value: 16.774182968018486.
# [I 2026-04-24 14:37:52,983] Trial 7 finished with value: 24.82065903687863 and parameters: {'alpha': 2.1423021757741068}. Best is trial 4 with value: 16.774182968018486.
# [I 2026-04-24 14:38:02,199] Trial 8 finished with value: 18.63354178912611 and parameters: {'alpha': 0.10129197956845731}. Best is trial 4 with value: 16.774182968018486.
# [I 2026-04-24 14:38:06,061] Trial 9 finished with value: 20.22471993177422 and parameters: {'alpha': 0.3470266988650412}. Best is trial 4 with value: 16.774182968018486.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.430e+04, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 14:41:05,316] Trial 10 finished with value: 16.753083151484486 and parameters: {'alpha': 0.0036035178201071797}. Best is trial 10 with value: 16.753083151484486.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.705e+05, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 14:44:05,201] Trial 11 finished with value: 16.708637435795396 and parameters: {'alpha': 0.003320743169159833}. Best is trial 11 with value: 16.708637435795396.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.907e+04, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 14:46:48,230] Trial 12 finished with value: 17.188631259467662 and parameters: {'alpha': 0.005619762349131517}. Best is trial 11 with value: 16.708637435795396.
# [I 2026-04-24 14:48:56,205] Trial 13 finished with value: 17.203803663918933 and parameters: {'alpha': 0.006357571098783772}. Best is trial 11 with value: 16.708637435795396.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.502e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 14:52:10,370] Trial 14 finished with value: 16.647294281315823 and parameters: {'alpha': 0.0011873946426630272}. Best is trial 14 with value: 16.647294281315823.
# =======================================================
#  [Lasso (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 20.7799
#  NASA Score : 849.1522
# =======================================================
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.502e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
#   [ElasticNet] Optuna 최적화 중...
# [I 2026-04-24 14:55:24,390] A new study created in memory with name: no-name-2dab71fd-0008-4dc4-90c6-029e92ad073a
# [I 2026-04-24 14:56:36,713] Trial 0 finished with value: 17.474789694944633 and parameters: {'alpha': 0.0074593432857265485, 'l1_ratio': 0.9056428757689245}. Best is trial 0 with value: 17.474789694944633.
# [I 2026-04-24 14:56:37,241] Trial 1 finished with value: 22.577441665492273 and parameters: {'alpha': 0.4570563099801455, 'l1_ratio': 0.588792635777333}. Best is trial 0 with value: 17.474789694944633.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.676e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 15:00:08,899] Trial 2 finished with value: 17.285245999103253 and parameters: {'alpha': 0.0006026889128682511, 'l1_ratio': 0.19039506830258235}. Best is trial 2 with value: 17.285245999103253.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.540e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 15:04:04,307] Trial 3 finished with value: 16.811423501515204 and parameters: {'alpha': 0.00019517224641449495, 'l1_ratio': 0.8295585311974416}. Best is trial 3 with value: 16.811423501515204.
# [I 2026-04-24 15:04:08,260] Trial 4 finished with value: 20.322084373806547 and parameters: {'alpha': 0.10129197956845731, 'l1_ratio': 0.6872653200164409}. Best is trial 3 with value: 16.811423501515204.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.554e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 15:07:57,865] Trial 5 finished with value: 16.489357018959957 and parameters: {'alpha': 0.00012674255898937226, 'l1_ratio': 0.9229188669457948}. Best is trial 5 with value: 16.489357018959957.
# [I 2026-04-24 15:07:58,023] Trial 6 finished with value: 28.972351185662447 and parameters: {'alpha': 1.452824663751602, 'l1_ratio': 0.24110519961044852}. Best is trial 5 with value: 16.489357018959957.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.088e+05, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 15:11:32,792] Trial 7 finished with value: 17.350791740279615 and parameters: {'alpha': 0.0008111941985431928, 'l1_ratio': 0.21506405886809044}. Best is trial 5 with value: 16.489357018959957.
# [I 2026-04-24 15:13:30,955] Trial 8 finished with value: 17.745051541992886 and parameters: {'alpha': 0.0033205591037519565, 'l1_ratio': 0.522280788469014}. Best is trial 5 with value: 16.489357018959957.
# [I 2026-04-24 15:13:55,573] Trial 9 finished with value: 19.267456230406765 and parameters: {'alpha': 0.01444525102276306, 'l1_ratio': 0.3121062261782377}. Best is trial 5 with value: 16.489357018959957.
# [I 2026-04-24 15:13:55,705] Trial 10 finished with value: 38.010741494925846 and parameters: {'alpha': 5.3171966339820935, 'l1_ratio': 0.7425875019070267}. Best is trial 5 with value: 16.489357018959957.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.575e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 15:17:33,259] Trial 11 finished with value: 16.48862430569618 and parameters: {'alpha': 0.00010907785690006128, 'l1_ratio': 0.90870963917974}. Best is trial 11 with value: 16.48862430569618.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.576e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 15:21:23,037] Trial 12 finished with value: 16.46527418095466 and parameters: {'alpha': 0.00011819129956743128, 'l1_ratio': 0.866898315754266}. Best is trial 12 with value: 16.46527418095466.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.417e+04, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 15:24:57,342] Trial 13 finished with value: 17.40013547901143 and parameters: {'alpha': 0.0012363585067294313, 'l1_ratio': 0.4032076028923692}. Best is trial 12 with value: 16.46527418095466.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.800e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 15:28:25,441] Trial 14 finished with value: 17.09540418104486 and parameters: {'alpha': 0.00012369791472859374, 'l1_ratio': 0.061859059217006296}. Best is trial 12 with value: 16.46527418095466.
# =======================================================
#  [ElasticNet (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 20.6246
#  NASA Score : 828.3460
# =======================================================
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.576e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# === 5. 트리 모델 학습 (Optuna) ===
# 피처 수: 87개 | Trials: 30
#
#   [RandomForest] Optuna 최적화 중...
# [I 2026-04-24 15:31:51,157] A new study created in memory with name: no-name-71aad9b0-55f2-4fd4-96fc-68d0e0d8e7aa
# [I 2026-04-24 15:31:59,702] Trial 0 finished with value: 15.191199123027049 and parameters: {'n_estimators': 175, 'max_depth': 29, 'min_samples_split': 15}. Best is trial 0 with value: 15.191199123027049.
# [I 2026-04-24 15:32:06,908] Trial 1 finished with value: 15.294872849885753 and parameters: {'n_estimators': 220, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 0 with value: 15.191199123027049.
# [I 2026-04-24 15:32:12,678] Trial 2 finished with value: 15.173258787713253 and parameters: {'n_estimators': 111, 'max_depth': 27, 'min_samples_split': 13}. Best is trial 2 with value: 15.173258787713253.
# [I 2026-04-24 15:32:17,315] Trial 3 finished with value: 16.194719973926944 and parameters: {'n_estimators': 242, 'max_depth': 5, 'min_samples_split': 20}. Best is trial 2 with value: 15.173258787713253.
# [I 2026-04-24 15:32:26,199] Trial 4 finished with value: 15.17152354447176 and parameters: {'n_estimators': 267, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 4 with value: 15.17152354447176.
# [I 2026-04-24 15:32:32,747] Trial 5 finished with value: 15.137414433266274 and parameters: {'n_estimators': 136, 'max_depth': 12, 'min_samples_split': 11}. Best is trial 5 with value: 15.137414433266274.
# [I 2026-04-24 15:32:41,991] Trial 6 finished with value: 15.140993616082747 and parameters: {'n_estimators': 186, 'max_depth': 12, 'min_samples_split': 13}. Best is trial 5 with value: 15.137414433266274.
# [I 2026-04-24 15:32:48,310] Trial 7 finished with value: 15.128266811891054 and parameters: {'n_estimators': 128, 'max_depth': 12, 'min_samples_split': 8}. Best is trial 7 with value: 15.128266811891054.
# [I 2026-04-24 15:33:01,237] Trial 8 finished with value: 15.151492434768175 and parameters: {'n_estimators': 191, 'max_depth': 25, 'min_samples_split': 5}. Best is trial 7 with value: 15.128266811891054.
# [I 2026-04-24 15:33:14,337] Trial 9 finished with value: 15.138946510666988 and parameters: {'n_estimators': 203, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 7 with value: 15.128266811891054.
# [I 2026-04-24 15:33:22,685] Trial 10 finished with value: 15.160020759244054 and parameters: {'n_estimators': 141, 'max_depth': 17, 'min_samples_split': 8}. Best is trial 7 with value: 15.128266811891054.
# [I 2026-04-24 15:33:28,277] Trial 11 finished with value: 15.143014216233125 and parameters: {'n_estimators': 101, 'max_depth': 15, 'min_samples_split': 9}. Best is trial 7 with value: 15.128266811891054.
# [I 2026-04-24 15:33:37,748] Trial 12 finished with value: 15.14366474709203 and parameters: {'n_estimators': 151, 'max_depth': 21, 'min_samples_split': 9}. Best is trial 7 with value: 15.128266811891054.
# [I 2026-04-24 15:33:41,347] Trial 13 finished with value: 16.20737996022829 and parameters: {'n_estimators': 146, 'max_depth': 5, 'min_samples_split': 16}. Best is trial 7 with value: 15.128266811891054.
# [I 2026-04-24 15:33:48,084] Trial 14 finished with value: 15.108398990120254 and parameters: {'n_estimators': 126, 'max_depth': 13, 'min_samples_split': 11}. Best is trial 14 with value: 15.108398990120254.
# [I 2026-04-24 15:33:55,028] Trial 15 finished with value: 15.104651417523652 and parameters: {'n_estimators': 123, 'max_depth': 15, 'min_samples_split': 7}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:34:03,751] Trial 16 finished with value: 15.122135857785183 and parameters: {'n_estimators': 161, 'max_depth': 15, 'min_samples_split': 11}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:34:21,882] Trial 17 finished with value: 15.121042268515547 and parameters: {'n_estimators': 297, 'max_depth': 21, 'min_samples_split': 7}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:34:29,029] Trial 18 finished with value: 15.1359636503246 and parameters: {'n_estimators': 121, 'max_depth': 18, 'min_samples_split': 17}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:34:35,749] Trial 19 finished with value: 15.316719914750767 and parameters: {'n_estimators': 168, 'max_depth': 9, 'min_samples_split': 13}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:34:41,587] Trial 20 finished with value: 15.11540946313076 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 2}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:34:47,766] Trial 21 finished with value: 15.127420212816899 and parameters: {'n_estimators': 107, 'max_depth': 15, 'min_samples_split': 2}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:34:56,004] Trial 22 finished with value: 15.119100000550429 and parameters: {'n_estimators': 128, 'max_depth': 18, 'min_samples_split': 6}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:35:01,693] Trial 23 finished with value: 15.11919882390621 and parameters: {'n_estimators': 100, 'max_depth': 14, 'min_samples_split': 3}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:35:09,885] Trial 24 finished with value: 15.138449868096089 and parameters: {'n_estimators': 124, 'max_depth': 24, 'min_samples_split': 10}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:35:14,881] Trial 25 finished with value: 15.618473815718827 and parameters: {'n_estimators': 155, 'max_depth': 7, 'min_samples_split': 6}. Best is trial 15 with value: 15.104651417523652.
# [I 2026-04-24 15:35:21,177] Trial 26 finished with value: 15.093580301947844 and parameters: {'n_estimators': 119, 'max_depth': 13, 'min_samples_split': 4}. Best is trial 26 with value: 15.093580301947844.
# [I 2026-04-24 15:35:27,305] Trial 27 finished with value: 15.115807603494977 and parameters: {'n_estimators': 121, 'max_depth': 13, 'min_samples_split': 11}. Best is trial 26 with value: 15.093580301947844.
# [I 2026-04-24 15:35:40,714] Trial 28 finished with value: 15.128672705555925 and parameters: {'n_estimators': 217, 'max_depth': 17, 'min_samples_split': 4}. Best is trial 26 with value: 15.093580301947844.
# [I 2026-04-24 15:35:47,748] Trial 29 finished with value: 15.21427293445184 and parameters: {'n_estimators': 164, 'max_depth': 10, 'min_samples_split': 7}. Best is trial 26 with value: 15.093580301947844.
# =======================================================
#  [RandomForest (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 18.0820
#  NASA Score : 593.6234
# =======================================================
#   [XGBoost] Optuna 최적화 중...
# [I 2026-04-24 15:35:54,302] A new study created in memory with name: no-name-e0b0f234-0601-4175-b135-54bbec6b4b92
# [I 2026-04-24 15:35:59,628] Trial 0 finished with value: 15.175689249238504 and parameters: {'n_estimators': 287, 'max_depth': 10, 'learning_rate': 0.1205712628744377}. Best is trial 0 with value: 15.175689249238504.
# [I 2026-04-24 15:36:00,186] Trial 1 finished with value: 14.763379252168502 and parameters: {'n_estimators': 399, 'max_depth': 4, 'learning_rate': 0.01699897838270077}. Best is trial 1 with value: 14.763379252168502.
# [I 2026-04-24 15:36:02,354] Trial 2 finished with value: 15.071758289901638 and parameters: {'n_estimators': 129, 'max_depth': 9, 'learning_rate': 0.07725378389307355}. Best is trial 1 with value: 14.763379252168502.
# [I 2026-04-24 15:36:02,797] Trial 3 finished with value: 15.173180379605038 and parameters: {'n_estimators': 454, 'max_depth': 3, 'learning_rate': 0.2708160864249968}. Best is trial 1 with value: 14.763379252168502.
# [I 2026-04-24 15:36:03,488] Trial 4 finished with value: 14.586211060470294 and parameters: {'n_estimators': 517, 'max_depth': 4, 'learning_rate': 0.01855998084649059}. Best is trial 4 with value: 14.586211060470294.
# [I 2026-04-24 15:36:03,954] Trial 5 finished with value: 14.514360879933008 and parameters: {'n_estimators': 191, 'max_depth': 5, 'learning_rate': 0.05958389350068958}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:04,515] Trial 6 finished with value: 14.621658856465082 and parameters: {'n_estimators': 316, 'max_depth': 5, 'learning_rate': 0.08012737503998542}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:04,854] Trial 7 finished with value: 14.703143161353024 and parameters: {'n_estimators': 169, 'max_depth': 5, 'learning_rate': 0.03476649150592621}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:09,590] Trial 8 finished with value: 14.84620251121162 and parameters: {'n_estimators': 328, 'max_depth': 9, 'learning_rate': 0.019721610970574007}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:11,194] Trial 9 finished with value: 14.871574456211441 and parameters: {'n_estimators': 357, 'max_depth': 7, 'learning_rate': 0.011711509955524094}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:12,144] Trial 10 finished with value: 14.827841495742108 and parameters: {'n_estimators': 204, 'max_depth': 7, 'learning_rate': 0.03847827279293917}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:13,177] Trial 11 finished with value: 14.595367407361124 and parameters: {'n_estimators': 577, 'max_depth': 5, 'learning_rate': 0.03220579752389848}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:13,737] Trial 12 finished with value: 14.907970145279306 and parameters: {'n_estimators': 586, 'max_depth': 3, 'learning_rate': 0.14371958988028352}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:14,952] Trial 13 finished with value: 14.719935926214998 and parameters: {'n_estimators': 477, 'max_depth': 6, 'learning_rate': 0.047613701494325505}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:15,300] Trial 14 finished with value: 14.84645740112035 and parameters: {'n_estimators': 239, 'max_depth': 4, 'learning_rate': 0.022882334359953335}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:16,668] Trial 15 finished with value: 14.771075692854039 and parameters: {'n_estimators': 493, 'max_depth': 6, 'learning_rate': 0.01084711736206481}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:16,858] Trial 16 finished with value: 14.710315142172558 and parameters: {'n_estimators': 108, 'max_depth': 4, 'learning_rate': 0.06907488839612538}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:17,357] Trial 17 finished with value: 14.723829425597865 and parameters: {'n_estimators': 532, 'max_depth': 3, 'learning_rate': 0.12808381038126324}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:18,445] Trial 18 finished with value: 14.611476286050376 and parameters: {'n_estimators': 414, 'max_depth': 6, 'learning_rate': 0.02418149308709178}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:20,504] Trial 19 finished with value: 14.920763415730548 and parameters: {'n_estimators': 271, 'max_depth': 8, 'learning_rate': 0.05343674182403084}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:21,244] Trial 20 finished with value: 14.5167139997853 and parameters: {'n_estimators': 382, 'max_depth': 5, 'learning_rate': 0.02719055151656567}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:21,936] Trial 21 finished with value: 14.689878879824239 and parameters: {'n_estimators': 376, 'max_depth': 5, 'learning_rate': 0.015006859180486139}. Best is trial 5 with value: 14.514360879933008.
# [I 2026-04-24 15:36:22,640] Trial 22 finished with value: 14.442518278628407 and parameters: {'n_estimators': 543, 'max_depth': 4, 'learning_rate': 0.027272820294897776}. Best is trial 22 with value: 14.442518278628407.
# [I 2026-04-24 15:36:23,437] Trial 23 finished with value: 14.526668884734681 and parameters: {'n_estimators': 436, 'max_depth': 5, 'learning_rate': 0.028393219022735006}. Best is trial 22 with value: 14.442518278628407.
# [I 2026-04-24 15:36:23,714] Trial 24 finished with value: 14.568148716678108 and parameters: {'n_estimators': 185, 'max_depth': 4, 'learning_rate': 0.04795031559490432}. Best is trial 22 with value: 14.442518278628407.
# [I 2026-04-24 15:36:24,366] Trial 25 finished with value: 14.663770100641006 and parameters: {'n_estimators': 239, 'max_depth': 6, 'learning_rate': 0.04121749594298619}. Best is trial 22 with value: 14.442518278628407.
# [I 2026-04-24 15:36:26,644] Trial 26 finished with value: 14.754249090039707 and parameters: {'n_estimators': 569, 'max_depth': 7, 'learning_rate': 0.06368328619031147}. Best is trial 22 with value: 14.442518278628407.
# [I 2026-04-24 15:36:27,644] Trial 27 finished with value: 14.5225370804124 and parameters: {'n_estimators': 532, 'max_depth': 5, 'learning_rate': 0.026826936967540925}. Best is trial 22 with value: 14.442518278628407.
# [I 2026-04-24 15:36:27,855] Trial 28 finished with value: 14.639392519995226 and parameters: {'n_estimators': 151, 'max_depth': 3, 'learning_rate': 0.09268705850324319}. Best is trial 22 with value: 14.442518278628407.
# [I 2026-04-24 15:36:28,235] Trial 29 finished with value: 14.858437429346226 and parameters: {'n_estimators': 280, 'max_depth': 4, 'learning_rate': 0.1861260249282727}. Best is trial 22 with value: 14.442518278628407.
# =======================================================
#  [XGBoost (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 18.5765
#  NASA Score : 554.8245
# =======================================================
#   [LightGBM] Optuna 최적화 중...
# [I 2026-04-24 15:36:29,069] A new study created in memory with name: no-name-6c56a3b4-3a78-4ad6-98a3-61712f91b322
# [I 2026-04-24 15:36:29,999] Trial 0 finished with value: 14.990991708419838 and parameters: {'n_estimators': 287, 'max_depth': 12, 'learning_rate': 0.1205712628744377, 'num_leaves': 128}. Best is trial 0 with value: 14.990991708419838.
# [I 2026-04-24 15:36:30,169] Trial 1 finished with value: 16.287685843236417 and parameters: {'n_estimators': 178, 'max_depth': 4, 'learning_rate': 0.012184186502221764, 'num_leaves': 176}. Best is trial 0 with value: 14.990991708419838.
# [I 2026-04-24 15:36:32,141] Trial 2 finished with value: 14.904386498204378 and parameters: {'n_estimators': 401, 'max_depth': 10, 'learning_rate': 0.010725209743171996, 'num_leaves': 195}. Best is trial 2 with value: 14.904386498204378.
# [I 2026-04-24 15:36:32,636] Trial 3 finished with value: 14.509056332873163 and parameters: {'n_estimators': 517, 'max_depth': 5, 'learning_rate': 0.01855998084649059, 'num_leaves': 53}. Best is trial 3 with value: 14.509056332873163.
# [I 2026-04-24 15:36:33,131] Trial 4 finished with value: 14.593232652872876 and parameters: {'n_estimators': 252, 'max_depth': 8, 'learning_rate': 0.04345454109729477, 'num_leaves': 72}. Best is trial 3 with value: 14.509056332873163.
# [I 2026-04-24 15:36:33,411] Trial 5 finished with value: 14.477066185676373 and parameters: {'n_estimators': 406, 'max_depth': 4, 'learning_rate': 0.027010527749605478, 'num_leaves': 86}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:34,435] Trial 6 finished with value: 14.592665226786847 and parameters: {'n_estimators': 328, 'max_depth': 10, 'learning_rate': 0.019721610970574007, 'num_leaves': 113}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:34,651] Trial 7 finished with value: 14.500170300549101 and parameters: {'n_estimators': 396, 'max_depth': 3, 'learning_rate': 0.07896186801026692, 'num_leaves': 50}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:35,184] Trial 8 finished with value: 15.7787427051374 and parameters: {'n_estimators': 132, 'max_depth': 12, 'learning_rate': 0.26690431824362526, 'num_leaves': 166}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:35,330] Trial 9 finished with value: 14.502373594318465 and parameters: {'n_estimators': 252, 'max_depth': 3, 'learning_rate': 0.1024932221692416, 'num_leaves': 99}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:35,832] Trial 10 finished with value: 14.641793919426474 and parameters: {'n_estimators': 578, 'max_depth': 6, 'learning_rate': 0.03550449468859506, 'num_leaves': 23}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:36,037] Trial 11 finished with value: 14.486990533446342 and parameters: {'n_estimators': 426, 'max_depth': 3, 'learning_rate': 0.08336421322449966, 'num_leaves': 61}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:36,606] Trial 12 finished with value: 15.207424455203412 and parameters: {'n_estimators': 464, 'max_depth': 6, 'learning_rate': 0.18566869441709818, 'num_leaves': 84}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:37,088] Trial 13 finished with value: 14.559717481101783 and parameters: {'n_estimators': 455, 'max_depth': 5, 'learning_rate': 0.03205809078417295, 'num_leaves': 132}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:37,287] Trial 14 finished with value: 14.56970283655501 and parameters: {'n_estimators': 383, 'max_depth': 3, 'learning_rate': 0.06241356234816455, 'num_leaves': 21}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:38,045] Trial 15 finished with value: 14.50460814898964 and parameters: {'n_estimators': 482, 'max_depth': 7, 'learning_rate': 0.022584683707525977, 'num_leaves': 59}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:38,403] Trial 16 finished with value: 14.523583024605976 and parameters: {'n_estimators': 582, 'max_depth': 4, 'learning_rate': 0.05756171095119272, 'num_leaves': 82}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:38,825] Trial 17 finished with value: 14.966580888296171 and parameters: {'n_estimators': 338, 'max_depth': 8, 'learning_rate': 0.13460704021152495, 'num_leaves': 39}. Best is trial 5 with value: 14.477066185676373.
# [I 2026-04-24 15:36:39,157] Trial 18 finished with value: 14.43570245297398 and parameters: {'n_estimators': 528, 'max_depth': 4, 'learning_rate': 0.027782172711792813, 'num_leaves': 102}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:39,681] Trial 19 finished with value: 14.498458620100134 and parameters: {'n_estimators': 543, 'max_depth': 5, 'learning_rate': 0.016034055878559182, 'num_leaves': 139}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:40,332] Trial 20 finished with value: 14.679063808903594 and parameters: {'n_estimators': 516, 'max_depth': 6, 'learning_rate': 0.028414636158561983, 'num_leaves': 107}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:40,631] Trial 21 finished with value: 14.471790617383085 and parameters: {'n_estimators': 419, 'max_depth': 4, 'learning_rate': 0.050776117920275775, 'num_leaves': 88}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:40,938] Trial 22 finished with value: 14.451721940269177 and parameters: {'n_estimators': 483, 'max_depth': 4, 'learning_rate': 0.04555799779284799, 'num_leaves': 97}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:41,236] Trial 23 finished with value: 14.476779026017846 and parameters: {'n_estimators': 499, 'max_depth': 4, 'learning_rate': 0.045556231219932415, 'num_leaves': 99}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:42,148] Trial 24 finished with value: 14.814078880770047 and parameters: {'n_estimators': 546, 'max_depth': 7, 'learning_rate': 0.042757625042867, 'num_leaves': 147}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:42,540] Trial 25 finished with value: 14.631917487216207 and parameters: {'n_estimators': 455, 'max_depth': 5, 'learning_rate': 0.0697076466712445, 'num_leaves': 117}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:42,846] Trial 26 finished with value: 14.543042063223952 and parameters: {'n_estimators': 438, 'max_depth': 4, 'learning_rate': 0.05027554772754654, 'num_leaves': 95}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:43,953] Trial 27 finished with value: 14.499784104849203 and parameters: {'n_estimators': 597, 'max_depth': 9, 'learning_rate': 0.03745314096465287, 'num_leaves': 74}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:44,495] Trial 28 finished with value: 14.625775328087476 and parameters: {'n_estimators': 373, 'max_depth': 6, 'learning_rate': 0.0247986925209533, 'num_leaves': 123}. Best is trial 18 with value: 14.43570245297398.
# [I 2026-04-24 15:36:45,078] Trial 29 finished with value: 14.47777878726939 and parameters: {'n_estimators': 552, 'max_depth': 5, 'learning_rate': 0.014724642463339412, 'num_leaves': 156}. Best is trial 18 with value: 14.43570245297398.
# =======================================================
#  [LightGBM (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 18.5554
#  NASA Score : 566.9958
# =======================================================
