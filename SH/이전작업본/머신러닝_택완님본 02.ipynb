# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.ndimage import gaussian_filter1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# ==========================================
# [실험 설정 구간] 모든 하이퍼파라미터 통합 
# ==========================================
DATA_PATH = './CMAPSSData/'
CONFIG = {
    'DATA_ID': 'FD001',
    'RUL_CAP': 125,
    'GAUSS_SIGMA': 2,
    'RANDOM_STATE': 42,
    'TEST_SIZE': 0.2,
    'SCALER_TYPE': 'minmax',  # minmax , Standard
    
    # 사용할 센서 직접 지정 (상수 센서 자동 감지 대신 사용)
    'BASE_SENSORS': ['s_2', 's_3', 's_4', 's_7', 's_8', 's_9', 's_11', 
                     's_12', 's_13', 's_14', 's_15', 's_17', 's_20', 's_21'],
    'SETTING_FEATURES': ['setting_1', 'setting_2', 'setting_3'],

    # 파생변수 설정 (리스트 형식 지원)
    'USE_MA': True,   'WIN_MA': [3, 5],
    'USE_STD': True,  'WIN_STD': [5],  
    'USE_DIFF': True, 'PER_DIFF': [1],
    'USE_EMA': True,  'SPAN_EMA': [3, 5],
    'USE_LAG': True,  'LAG_STEP': [1, 3, 5],
}

# ---------------------------------------------------------
# [1] 데이터 로드 및 초기 전처리 (Capping & 상수 제거)
# ---------------------------------------------------------
def load_and_basic_prep(config):
    # 전체 컬럼 정의
    cols = ['unit_nr', 'time_cycles', 'setting_1', 'setting_2', 'setting_3'] + [f's_{i}' for i in range(1, 22)]
    
    # 데이터 로드
    train = pd.read_csv(f"{DATA_PATH}train_{config['DATA_ID']}.txt", sep='\s+', header=None, names=cols)
    test = pd.read_csv(f"{DATA_PATH}test_{config['DATA_ID']}.txt", sep='\s+', header=None, names=cols)
    y_test_final = pd.read_csv(f"{DATA_PATH}RUL_{config['DATA_ID']}.txt", sep='\s+', header=None, names=['RUL'])['RUL'].values

    # RUL 생성 및 Capping
    train['max_cycle'] = train.groupby('unit_nr')['time_cycles'].transform('max')
    train['RUL'] = (train['max_cycle'] - train['time_cycles']).clip(upper=config['RUL_CAP'])
    train.drop(columns=['max_cycle'], inplace=True)

    # 명시적으로 선택한 컬럼만 유지 (unit_nr, time_cycles, RUL + 선택 센서 + 세팅값)
    keep_cols = ['unit_nr', 'time_cycles'] + config['SETTING_FEATURES'] + config['BASE_SENSORS']
    
    # Train은 RUL 포함, Test는 RUL 제외하고 선택
    train = train[keep_cols + ['RUL']]
    test = test[keep_cols]
    
    print(f" 센서 선택 완료: {config['BASE_SENSORS']}")
    print(f" 유지된 컬럼 총 {len(train.columns)}개 (RUL 포함)")
    
    return train, test, y_test_final

# 실행 
df_train, df_test, y_test = load_and_basic_prep(CONFIG)

# ---------------------------------------------------------
# [2] 가우시안 스무딩 (Team Style)
# ---------------------------------------------------------
def apply_gaussian_smoothing(df, sigma):
    if sigma <= 0: return df.copy()
    df = df.copy().sort_values(['unit_nr', 'time_cycles']).reset_index(drop=True)
    sensors = [c for c in df.columns if c.startswith('s_')]
    
    for uid in df['unit_nr'].unique():
        mask = df['unit_nr'] == uid
        for col in sensors:
            arr = df.loc[mask, col].to_numpy(dtype=np.float32)
            df.loc[mask, col] = gaussian_filter1d(arr, sigma=sigma, mode='nearest')
    return df

df_train = apply_gaussian_smoothing(df_train, CONFIG['GAUSS_SIGMA'])
df_test = apply_gaussian_smoothing(df_test, CONFIG['GAUSS_SIGMA'])
print(f"✅ 가우시안 스무딩 완료 (Sigma: {CONFIG['GAUSS_SIGMA']})")

# ---------------------------------------------------------
# [3] 데이터 분할 (Train / Val)
# ---------------------------------------------------------
unit_ids = df_train['unit_nr'].unique()
train_units, val_units = train_test_split(unit_ids, test_size=CONFIG['TEST_SIZE'], random_state=CONFIG['RANDOM_STATE'])

train_set = df_train[df_train['unit_nr'].isin(train_units)].copy()
val_set = df_train[df_train['unit_nr'].isin(val_units)].copy()
test_set = df_test.copy()

# ---------------------------------------------------------
# [4] 정규화 (Base Sensors + Settings)
# ---------------------------------------------------------
base_sensors = sorted([c for c in df_train.columns if c.startswith('s_')], key=lambda x: int(x.split('_')[1]))
base_plus_setting = base_sensors + CONFIG['SETTING_FEATURES']

if CONFIG['SCALER_TYPE'] == 'minmax':
    scaler = MinMaxScaler()
else:
    scaler = StandardScaler()

train_set[base_plus_setting] = scaler.fit_transform(train_set[base_plus_setting])
val_set[base_plus_setting] = scaler.transform(val_set[base_plus_setting])
test_set[base_plus_setting] = scaler.transform(test_set[base_plus_setting])
print(f" 정규화 완료 ({CONFIG['SCALER_TYPE']})")

# ---------------------------------------------------------
# [5] 파생변수 생성 (다중 윈도우 지원 수정 버전)
# ---------------------------------------------------------
def add_features_final(df, features, config):
    df_res = df.copy()
    for col in features:
        group = df_res.groupby('unit_nr')[col]

        if config['USE_MA']:
            wins = config['WIN_MA'] if isinstance(config['WIN_MA'], list) else [config['WIN_MA']]
            for w in wins:
                df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
        
        if config['USE_STD']:
            wins = config['WIN_STD'] if isinstance(config['WIN_STD'], list) else [config['WIN_STD']]
            for w in wins:
                df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
            
        if config['USE_DIFF']:
            pers = config['PER_DIFF'] if isinstance(config['PER_DIFF'], list) else [config['PER_DIFF']]
            for p in pers:
                df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
            
        if config['USE_EMA']:
            spans = config['SPAN_EMA'] if isinstance(config['SPAN_EMA'], list) else [config['SPAN_EMA']]
            for s in spans:
                df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
            
        if config['USE_LAG']:
            steps = config['LAG_STEP'] if isinstance(config['LAG_STEP'], list) else [config['LAG_STEP']]
            for st in steps:
                df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
                
    return df_res

train_set = add_features_final(train_set, base_sensors, CONFIG)
val_set = add_features_final(val_set, base_sensors, CONFIG)
test_set = add_features_final(test_set, base_sensors, CONFIG)

# 최종 피처 리스트 구성 (다중 윈도우 컬럼명 자동 반영)
X_features_full = base_sensors + CONFIG['SETTING_FEATURES']
def get_derived_colnames(base_sensors, config, prefix, config_key):
    if not config[prefix]: return []
    vals = config[config_key] if isinstance(config[config_key], list) else [config[config_key]]
    suffix = 'ma' if config_key == 'WIN_MA' else 'std' if config_key == 'WIN_STD' else 'diff' if config_key == 'PER_DIFF' else 'ema' if config_key == 'SPAN_EMA' else 'lag'
    return [f'{c}_{suffix}{v}' for c in base_sensors for v in vals]

X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_MA', 'WIN_MA')
X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_STD', 'WIN_STD')
X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_DIFF', 'PER_DIFF')
X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_EMA', 'SPAN_EMA')
X_features_full += get_derived_colnames(base_sensors, CONFIG, 'USE_LAG', 'LAG_STEP')

# 최종 변수 할당
X_train, y_train = train_set[X_features_full], train_set['RUL']
X_val, y_val = val_set[X_features_full], val_set['RUL']
X_test = test_set.groupby('unit_nr').last()[X_features_full]

print(f"\n 전처리 파이프라인 완료")
print(f" 최종 피처 수: {len(X_features_full)}개")
print(f" X_train: {X_train.shape}, X_val: {X_val.shape}, X_test: {X_test.shape}")
print(f" y_train: {y_train.shape}, y_val: {y_val.shape}, y_test: {y_test.shape}")
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:44: SyntaxWarning: invalid escape sequence '\s'
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:44: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:42: SyntaxWarning: invalid escape sequence '\s'
#   train = pd.read_csv(f"{DATA_PATH}train_{config['DATA_ID']}.txt", sep='\s+', header=None, names=cols)
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:43: SyntaxWarning: invalid escape sequence '\s'
#   test = pd.read_csv(f"{DATA_PATH}test_{config['DATA_ID']}.txt", sep='\s+', header=None, names=cols)
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:44: SyntaxWarning: invalid escape sequence '\s'
#   y_test_final = pd.read_csv(f"{DATA_PATH}RUL_{config['DATA_ID']}.txt", sep='\s+', header=None, names=['RUL'])['RUL'].values
#  센서 선택 완료: ['s_2', 's_3', 's_4', 's_7', 's_8', 's_9', 's_11', 's_12', 's_13', 's_14', 's_15', 's_17', 's_20', 's_21']
#  유지된 컬럼 총 20개 (RUL 포함)
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:78: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[391.77582 391.68353 391.64896 391.67813 391.7251  391.75134 391.7735
#  391.8313  391.92657 392.0214  392.08725 392.12457 392.1319  392.09442
#  392.01413 391.9201  391.84152 391.7934  391.78723 391.8313  391.92325
#  392.05826 392.23425 392.42435 392.55026 392.51938 392.3118  392.01746
#  391.77063 391.65387 391.65915 391.71765 391.76212 391.77487 391.7844
#  391.81982 391.87827 391.9356  391.97565 392.00223 392.03354 392.0913
#  392.18576 392.2974  392.3773  392.38205 392.31525 392.22345 392.14755
#  392.08847 392.02478 391.94785 391.86353 391.77057 391.66293 391.55713
#  391.49835 391.52277 391.61795 391.73416 391.83292 391.90213 391.93484
#  391.93262 391.92432 391.94    391.96414 391.94235 391.83783 391.67056
#  391.50626 391.41058 391.4072  391.47897 391.6106  391.80786 392.05795
#  392.2931  392.42627 392.42255 392.32175 392.20245 392.13412 392.13864
#  392.17502 392.17664 392.1243  392.071   392.08588 392.1859  392.33176
#  392.4755  392.58728 392.63516 392.5806  392.4256  392.23752 392.09656
#  392.0326  392.03033 392.0741  392.1651  392.316   392.54474 392.8514
#  393.18127 393.42896 393.511   393.4394  393.31396 393.23843 393.2431
#  393.27734 393.2664  393.1794  393.06015 392.9943  393.0301  393.12717
#  393.19363 393.1729  393.08734 393.00104 392.95306 392.93594 392.9309
#  392.93317 392.93524 392.919   392.8851  392.8663  392.8854  392.92142
#  392.9443  392.96127 392.99976 393.06482 393.13437 393.17975 393.18176
#  393.14938 393.12347 393.1365  393.16638 393.16107 393.11877 393.1142
#  393.22583 393.45062 393.70282 393.88705 393.96622 393.96765 393.93585
#  393.89435 393.86307 393.88608 393.9952  394.1443  394.22467 394.1671
#  394.0107  393.86157 393.7977  393.81882 393.87604 393.93765 394.01343
#  394.11014 394.19003 394.20236 394.1476  394.09036 394.1142  394.2661
#  394.5264  394.82907 395.12427 395.41025 395.68817 395.90732 395.9982
#  395.96176 395.8879  395.86697 395.9072  395.9553  395.96823 395.94012
#  395.88693 395.83826 395.82684]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[mask, col] = gaussian_filter1d(arr, sigma=sigma, mode='nearest')
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:78: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[392.17642 392.11795 391.93655 391.69623 391.5161  391.4609  391.48407
#  391.48898 391.43274 391.35953 391.34018 391.39062 391.45013 391.43777
#  391.3329  391.20142 391.14267 391.21512 391.411   391.68246 391.9737
#  392.22977 392.39252 392.4173  392.3117  392.1463  392.01035 391.9618
#  392.0214  392.1852  392.41766]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[mask, col] = gaussian_filter1d(arr, sigma=sigma, mode='nearest')
# ✅ 가우시안 스무딩 완료 (Sigma: 2)
#  정규화 완료 (minmax)
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ma{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_std{w}'] = group.transform(lambda x: x.rolling(w, min_periods=1).std().fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_diff{p}'] = group.transform(lambda x: x.diff(p).fillna(0))
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_ema{s}'] = group.transform(lambda x: x.ewm(span=s, adjust=False).mean())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
# C:\Users\skrke\AppData\Local\Temp\ipykernel_24752\1209465253.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_res[f'{col}_lag{st}'] = group.transform(lambda x: x.shift(st).bfill())
#  전처리 파이프라인 완료
#  최종 피처 수: 143개
#  X_train: (16561, 143), X_val: (4070, 143), X_test: (100, 143)
#  y_train: (16561,), y_val: (4070,), y_test: (100,)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

def calculate_nasa_score(y_true, y_pred):
    """C-MAPSS 전용 NASA Score 계산 함수 ㅋ"""
    diff = y_pred - y_true
    # 조기 예측(diff < 0)보다 늦은 예측(diff > 0)에 더 큰 패널티 부여 
    score = np.where(diff < 0, np.exp(-diff/13)-1, np.exp(diff/10)-1)
    return np.sum(score)

def evaluate_model(y_true, y_pred, model_name):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    score = calculate_nasa_score(y_true, y_pred)
    print(f"[{model_name}] 평가 결과")
    print(f" RMSE: {rmse:.4f}")
    print(f" NASA Score: {score:.4f}")
    return rmse, score

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import time
import optuna
from optuna.samplers import TPESampler
import xgboost as xgb
import lightgbm as lgb

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

def report_performance(y_true, y_pred, model_name):
    """
    예측 결과를 평가하고 시각화하는 공통 함수
    """
    # 1. 지표 계산 (RMSE)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    
    # 2. NASA Score 계산 (비대칭 페널티)
    # 실제보다 늦게 예측할 때(Overestimation) 더 큰 페널티를 부여하는 방식
    d = y_pred - y_true
    nasa_score = np.sum(np.where(d < 0, np.exp(-d/13)-1, np.exp(d/10)-1))
    
    print(f"\n{'='*55}")
    print(f" [{model_name}] 모델 평가 결과")
    print(f"{'-'*55}")
    print(f" RMSE       : {rmse:.4f}")
    print(f" NASA Score : {nasa_score:.4f}")
    print(f"{'='*55}")
    
    # 3. 트렌드 시각화
    plt.figure(figsize=(15, 5))
    
    # 데이터가 너무 많으면 가독성을 위해 앞부분 일부만 출력
    display_step = min(100, len(y_true)) 
    
    plt.plot(y_true[:display_step], label='Actual RUL', color='black', linestyle='--', alpha=0.7, marker='o', markersize=4)
    plt.plot(y_pred[:display_step], label=f'Predicted (by {model_name})', color='crimson', linewidth=2, marker='x', markersize=4)
    
    # 오차 범위 시각화
    plt.fill_between(range(display_step), y_true[:display_step], y_pred[:display_step], color='crimson', alpha=0.1)
    
    plt.title(f'RUL Prediction Trend: {model_name}', fontsize=14, fontweight='bold')
    plt.xlabel('Test Unit Sample Index (Subset)')
    plt.ylabel('Remaining Useful Life (Cycles)')
    plt.legend(loc='upper right')
    plt.grid(True, linestyle=':', alpha=0.6)
    
    plt.tight_layout()
    plt.show()
    
    return rmse, nasa_score

# %%
# [사전 설정] 전처리 결과 연결
# FEATURES_LINEAR와 FEATURES_TREE를 동일하게 X_features_full로 사용하거나 
# 필요시 분리해서 정의
FEATURES_LINEAR = X_features_full 
FEATURES_TREE = X_features_full

# 하이퍼파라미터
N_TRIALS_LIN = 15
N_TRIALS_TRE = 30 

# ---------------------------------------------------------
# 4. 선형 모델 학습 (Optuna)
# ---------------------------------------------------------
print(f'=== 4. 선형 모델 학습 (Optuna) ===')
print(f'피처 수: {len(FEATURES_LINEAR)}개 | Trials: {N_TRIALS_LIN}\n')

def get_linear_model(trial, name):
    if name == 'Ridge':
        return Ridge(alpha=trial.suggest_float('alpha', 0.01, 500, log=True), 
                     random_state=CONFIG['RANDOM_STATE'])
    elif name == 'Lasso':
        return Lasso(alpha=trial.suggest_float('alpha', 1e-4, 10, log=True), 
                     max_iter=10000, random_state=CONFIG['RANDOM_STATE'])
    else:  # ElasticNet
        return ElasticNet(
            alpha=trial.suggest_float('alpha', 1e-4, 10, log=True),
            l1_ratio=trial.suggest_float('l1_ratio', 0.05, 0.95),
            max_iter=10000, random_state=CONFIG['RANDOM_STATE'])

linear_models = ['Ridge', 'Lasso', 'ElasticNet']
linear_results = {}

for mname in linear_models:
    t0 = time.time()
    print(f'  [{mname}] Optuna 최적화 중... ', end='', flush=True)

    def objective(trial):
        model = get_linear_model(trial, mname)
        model.fit(X_train[FEATURES_LINEAR], y_train)
        # 검증셋(X_val) 기준으로 점수 최적화 ㅋ
        preds = model.predict(X_val[FEATURES_LINEAR])
        return np.sqrt(mean_squared_error(y_val, preds))

    study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=CONFIG['RANDOM_STATE']))
    study.optimize(objective, n_trials=N_TRIALS_LIN)

    # 최적 파라미터로 최종 학습
    best_p = study.best_params
    best_m = get_linear_model(optuna.trial.FixedTrial(best_p), mname)
    best_m.fit(X_train[FEATURES_LINEAR], y_train)

    # 평가
    rmse, score = report_performance(y_test, best_m.predict(X_test[FEATURES_LINEAR]), f"{mname} (Optuna)")
    linear_results[mname] = {'rmse': rmse, 'score': score, 'time': time.time()-t0}

# ---------------------------------------------------------
# 5. 트리 모델 학습 (Optuna)
# ---------------------------------------------------------
print(f'\n=== 5. 트리 모델 학습 (Optuna) ===')
print(f'피처 수: {len(FEATURES_TREE)}개 | Trials: {N_TRIALS_TRE}\n')

def get_tree_model(trial, name):
    if name == 'RandomForest':
        return RandomForestRegressor(
            n_estimators=trial.suggest_int('n_estimators', 100, 300),
            max_depth=trial.suggest_int('max_depth', 5, 30),
            min_samples_split=trial.suggest_int('min_samples_split', 2, 20),
            random_state=CONFIG['RANDOM_STATE'], n_jobs=-1)
    elif name == 'XGBoost':
        return xgb.XGBRegressor(
            n_estimators=trial.suggest_int('n_estimators', 100, 600),
            max_depth=trial.suggest_int('max_depth', 3, 10),
            learning_rate=trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            tree_method='hist', random_state=CONFIG['RANDOM_STATE'], n_jobs=-1, verbosity=0)
    else:  # LightGBM
        return lgb.LGBMRegressor(
            n_estimators=trial.suggest_int('n_estimators', 100, 600),
            max_depth=trial.suggest_int('max_depth', 3, 12),
            learning_rate=trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            num_leaves=trial.suggest_int('num_leaves', 20, 200),
            random_state=CONFIG['RANDOM_STATE'], n_jobs=-1, verbose=-1)

tree_models = ['RandomForest', 'XGBoost', 'LightGBM']
tree_results = {}

for mname in tree_models:
    t0 = time.time()
    print(f'  [{mname}] Optuna 최적화 중... ', end='', flush=True)

    def objective(trial):
        model = get_tree_model(trial, mname)
        model.fit(X_train[FEATURES_TREE], y_train)
        preds = model.predict(X_val[FEATURES_TREE])
        return np.sqrt(mean_squared_error(y_val, preds))

    study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=CONFIG['RANDOM_STATE']))
    study.optimize(objective, n_trials=N_TRIALS_TRE)

    # 최적 파라미터로 최종 학습
    best_p = study.best_params
    if mname == 'RandomForest':
        best_m = RandomForestRegressor(**best_p, random_state=CONFIG['RANDOM_STATE'], n_jobs=-1)
    elif mname == 'XGBoost':
        best_m = xgb.XGBRegressor(**best_p, tree_method='hist', random_state=CONFIG['RANDOM_STATE'], n_jobs=-1, verbosity=0)
    else:
        best_m = lgb.LGBMRegressor(**best_p, random_state=CONFIG['RANDOM_STATE'], n_jobs=-1, verbose=-1)
    
    best_m.fit(X_train[FEATURES_TREE], y_train)

    # 평가 및 시각화 ㅋ
    rmse, score = report_performance(y_test, best_m.predict(X_test[FEATURES_TREE]), f"{mname} (Optuna)")
    tree_results[mname] = {'rmse': rmse, 'score': score, 'time': time.time()-t0}
# Out:
# === 4. 선형 모델 학습 (Optuna) ===
# 피처 수: 143개 | Trials: 15
#
#   [Ridge] Optuna 최적화 중...
# [I 2026-04-24 09:15:50,614] A new study created in memory with name: no-name-f329c575-ee72-47bd-899d-4c2374c2f457
# [I 2026-04-24 09:15:50,663] Trial 0 finished with value: 18.030504905477507 and parameters: {'alpha': 0.575377379411719}. Best is trial 0 with value: 18.030504905477507.
# [I 2026-04-24 09:15:50,704] Trial 1 finished with value: 19.79586386351322 and parameters: {'alpha': 293.34453957883983}. Best is trial 0 with value: 18.030504905477507.
# [I 2026-04-24 09:15:50,744] Trial 2 finished with value: 18.946009557748543 and parameters: {'alpha': 27.518044962720857}. Best is trial 0 with value: 18.030504905477507.
# [I 2026-04-24 09:15:50,784] Trial 3 finished with value: 18.592421413803645 and parameters: {'alpha': 6.502468545951018}. Best is trial 0 with value: 18.030504905477507.
# [I 2026-04-24 09:15:50,826] Trial 4 finished with value: 17.411235711582385 and parameters: {'alpha': 0.05409123677836541}. Best is trial 4 with value: 17.411235711582385.
# [I 2026-04-24 09:15:50,872] Trial 5 finished with value: 17.411170600301336 and parameters: {'alpha': 0.054077122202881224}. Best is trial 5 with value: 17.411170600301336.
# [I 2026-04-24 09:15:50,911] Trial 6 finished with value: 17.17676989571431 and parameters: {'alpha': 0.01874705922180252}. Best is trial 6 with value: 17.17676989571431.
# [I 2026-04-24 09:15:50,953] Trial 7 finished with value: 19.491269791161226 and parameters: {'alpha': 117.52647960576222}. Best is trial 6 with value: 17.17676989571431.
# [I 2026-04-24 09:15:50,993] Trial 8 finished with value: 18.59755329947455 and parameters: {'alpha': 6.677615511747083}. Best is trial 6 with value: 17.17676989571431.
# [I 2026-04-24 09:15:51,030] Trial 9 finished with value: 18.865859552545015 and parameters: {'alpha': 21.242802137208894}. Best is trial 6 with value: 17.17676989571431.
# [I 2026-04-24 09:15:51,075] Trial 10 finished with value: 17.10679344894895 and parameters: {'alpha': 0.012487365959463722}. Best is trial 10 with value: 17.10679344894895.
# [I 2026-04-24 09:15:51,115] Trial 11 finished with value: 17.076232516824927 and parameters: {'alpha': 0.010202072983241583}. Best is trial 11 with value: 17.076232516824927.
# [I 2026-04-24 09:15:51,156] Trial 12 finished with value: 17.892151662636724 and parameters: {'alpha': 0.3430415094200433}. Best is trial 11 with value: 17.076232516824927.
# [I 2026-04-24 09:15:51,195] Trial 13 finished with value: 17.081559891216628 and parameters: {'alpha': 0.010581949937500931}. Best is trial 11 with value: 17.076232516824927.
# [I 2026-04-24 09:15:51,236] Trial 14 finished with value: 17.866282959605037 and parameters: {'alpha': 0.3110558839147533}. Best is trial 11 with value: 17.076232516824927.
# =======================================================
#  [Ridge (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 22.1539
#  NASA Score : 1123.7454
# =======================================================
#   [Lasso] Optuna 최적화 중...
# [I 2026-04-24 09:15:51,400] A new study created in memory with name: no-name-4ca39f22-4d06-46f4-ab8b-de83e4b823e9
# [I 2026-04-24 09:17:09,119] Trial 0 finished with value: 18.551346074632853 and parameters: {'alpha': 0.0074593432857265485}. Best is trial 0 with value: 18.551346074632853.
# [I 2026-04-24 09:17:09,176] Trial 1 finished with value: 37.56381259428765 and parameters: {'alpha': 5.669849511478847}. Best is trial 0 with value: 18.551346074632853.
# [I 2026-04-24 09:17:14,283] Trial 2 finished with value: 20.446538985243443 and parameters: {'alpha': 0.4570563099801455}. Best is trial 0 with value: 18.551346074632853.
# [I 2026-04-24 09:17:24,355] Trial 3 finished with value: 19.674314129856857 and parameters: {'alpha': 0.09846738873614563}. Best is trial 0 with value: 18.551346074632853.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.611e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 09:21:56,634] Trial 4 finished with value: 17.408148304628074 and parameters: {'alpha': 0.0006026889128682511}. Best is trial 4 with value: 17.408148304628074.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.612e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 09:26:22,732] Trial 5 finished with value: 17.408078974715743 and parameters: {'alpha': 0.000602521573620386}. Best is trial 5 with value: 17.408078974715743.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.188e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 09:31:17,406] Trial 6 finished with value: 17.256479701845947 and parameters: {'alpha': 0.00019517224641449495}. Best is trial 6 with value: 17.256479701845947.
# [I 2026-04-24 09:31:18,590] Trial 7 finished with value: 24.82065903687863 and parameters: {'alpha': 2.1423021757741068}. Best is trial 6 with value: 17.256479701845947.
# [I 2026-04-24 09:31:28,152] Trial 8 finished with value: 19.699842434506238 and parameters: {'alpha': 0.10129197956845731}. Best is trial 6 with value: 17.256479701845947.
# [I 2026-04-24 09:31:33,534] Trial 9 finished with value: 20.224719587646284 and parameters: {'alpha': 0.3470266988650412}. Best is trial 6 with value: 17.256479701845947.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.394e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 09:36:59,944] Trial 10 finished with value: 17.23615100272049 and parameters: {'alpha': 0.00012666337284957855}. Best is trial 10 with value: 17.23615100272049.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 09:42:35,222] Trial 11 finished with value: 17.22835304732992 and parameters: {'alpha': 0.00010215156685612682}. Best is trial 11 with value: 17.22835304732992.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.208e+04, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 09:46:31,008] Trial 12 finished with value: 18.360990981464678 and parameters: {'alpha': 0.004302348135499108}. Best is trial 11 with value: 17.22835304732992.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.447e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 09:51:52,070] Trial 13 finished with value: 17.229553282117507 and parameters: {'alpha': 0.00010620365287471019}. Best is trial 11 with value: 17.22835304732992.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.123e+04, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 09:55:27,516] Trial 14 finished with value: 18.313877300745162 and parameters: {'alpha': 0.0038768061930617363}. Best is trial 11 with value: 17.22835304732992.
# =======================================================
#  [Lasso (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 22.3217
#  NASA Score : 1165.6043
# =======================================================
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
#   [ElasticNet] Optuna 최적화 중...
# [I 2026-04-24 10:00:33,588] A new study created in memory with name: no-name-560d5f7a-bea3-4964-96b7-49f76e13da5b
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.124e+04, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:05:01,256] Trial 0 finished with value: 18.804782257528405 and parameters: {'alpha': 0.0074593432857265485, 'l1_ratio': 0.9056428757689245}. Best is trial 0 with value: 18.804782257528405.
# [I 2026-04-24 10:05:03,526] Trial 1 finished with value: 21.30554028085858 and parameters: {'alpha': 0.4570563099801455, 'l1_ratio': 0.588792635777333}. Best is trial 0 with value: 18.804782257528405.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.204e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:10:22,797] Trial 2 finished with value: 18.619533669264733 and parameters: {'alpha': 0.0006026889128682511, 'l1_ratio': 0.19039506830258235}. Best is trial 2 with value: 18.619533669264733.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.651e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:15:26,065] Trial 3 finished with value: 18.03020198187336 and parameters: {'alpha': 0.00019517224641449495, 'l1_ratio': 0.8295585311974416}. Best is trial 3 with value: 18.03020198187336.
# [I 2026-04-24 10:15:48,882] Trial 4 finished with value: 20.12397190366446 and parameters: {'alpha': 0.10129197956845731, 'l1_ratio': 0.6872653200164409}. Best is trial 3 with value: 18.03020198187336.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.621e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:20:51,219] Trial 5 finished with value: 17.805403921270837 and parameters: {'alpha': 0.00012674255898937226, 'l1_ratio': 0.9229188669457948}. Best is trial 5 with value: 17.805403921270837.
# [I 2026-04-24 10:20:51,629] Trial 6 finished with value: 25.134752055729507 and parameters: {'alpha': 1.452824663751602, 'l1_ratio': 0.24110519961044852}. Best is trial 5 with value: 17.805403921270837.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.110e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:26:09,152] Trial 7 finished with value: 18.70375203839794 and parameters: {'alpha': 0.0008111941985431928, 'l1_ratio': 0.21506405886809044}. Best is trial 5 with value: 17.805403921270837.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.308e+05, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:31:36,313] Trial 8 finished with value: 18.95506803602532 and parameters: {'alpha': 0.0033205591037519565, 'l1_ratio': 0.522280788469014}. Best is trial 5 with value: 17.805403921270837.
# [I 2026-04-24 10:34:04,085] Trial 9 finished with value: 19.643469057749865 and parameters: {'alpha': 0.01444525102276306, 'l1_ratio': 0.3121062261782377}. Best is trial 5 with value: 17.805403921270837.
# [I 2026-04-24 10:34:04,397] Trial 10 finished with value: 35.96771471867024 and parameters: {'alpha': 5.3171966339820935, 'l1_ratio': 0.7425875019070267}. Best is trial 5 with value: 17.805403921270837.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.677e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:39:44,455] Trial 11 finished with value: 17.8065318833307 and parameters: {'alpha': 0.00010907785690006128, 'l1_ratio': 0.90870963917974}. Best is trial 5 with value: 17.805403921270837.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.706e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:45:16,562] Trial 12 finished with value: 17.895998519073114 and parameters: {'alpha': 0.00011819129956743128, 'l1_ratio': 0.866898315754266}. Best is trial 5 with value: 17.805403921270837.
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.656e+05, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# [I 2026-04-24 10:50:01,450] Trial 13 finished with value: 18.34085120310606 and parameters: {'alpha': 0.0012444106742791423, 'l1_ratio': 0.9379545190369877}. Best is trial 5 with value: 17.805403921270837.
# [I 2026-04-24 10:50:28,880] Trial 14 finished with value: 20.03400237080807 and parameters: {'alpha': 0.05467530386354753, 'l1_ratio': 0.3916438190782011}. Best is trial 5 with value: 17.805403921270837.
# =======================================================
#  [ElasticNet (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 22.4627
#  NASA Score : 1321.1385
# =======================================================
# c:\python_course\4project_cmapss\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.621e+06, tolerance: 2.874e+03
#   model = cd_fast.enet_coordinate_descent(
# === 5. 트리 모델 학습 (Optuna) ===
# 피처 수: 143개 | Trials: 30
#
#   [RandomForest] Optuna 최적화 중...
# [I 2026-04-24 10:55:38,089] A new study created in memory with name: no-name-dd652b1f-c1d4-44bf-9fae-c917e52ebf16
# [I 2026-04-24 10:55:52,994] Trial 0 finished with value: 15.831932256019078 and parameters: {'n_estimators': 175, 'max_depth': 29, 'min_samples_split': 15}. Best is trial 0 with value: 15.831932256019078.
# [I 2026-04-24 10:56:06,340] Trial 1 finished with value: 15.705109426150846 and parameters: {'n_estimators': 220, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 1 with value: 15.705109426150846.
# [I 2026-04-24 10:56:19,058] Trial 2 finished with value: 15.802155467061718 and parameters: {'n_estimators': 111, 'max_depth': 27, 'min_samples_split': 13}. Best is trial 1 with value: 15.705109426150846.
# [I 2026-04-24 10:56:28,767] Trial 3 finished with value: 16.21648378036481 and parameters: {'n_estimators': 242, 'max_depth': 5, 'min_samples_split': 20}. Best is trial 1 with value: 15.705109426150846.
# [I 2026-04-24 10:56:48,129] Trial 4 finished with value: 15.71165175503832 and parameters: {'n_estimators': 267, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 1 with value: 15.705109426150846.
# [I 2026-04-24 10:56:59,060] Trial 5 finished with value: 15.715443363182954 and parameters: {'n_estimators': 136, 'max_depth': 12, 'min_samples_split': 11}. Best is trial 1 with value: 15.705109426150846.
# [I 2026-04-24 10:57:14,255] Trial 6 finished with value: 15.719353676673094 and parameters: {'n_estimators': 186, 'max_depth': 12, 'min_samples_split': 13}. Best is trial 1 with value: 15.705109426150846.
# [I 2026-04-24 10:57:25,549] Trial 7 finished with value: 15.695130110672064 and parameters: {'n_estimators': 128, 'max_depth': 12, 'min_samples_split': 8}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 10:57:47,729] Trial 8 finished with value: 15.789130319583439 and parameters: {'n_estimators': 191, 'max_depth': 25, 'min_samples_split': 5}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 10:58:10,731] Trial 9 finished with value: 15.778718600188611 and parameters: {'n_estimators': 203, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 10:58:25,312] Trial 10 finished with value: 15.763881127048089 and parameters: {'n_estimators': 141, 'max_depth': 17, 'min_samples_split': 8}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 10:58:34,077] Trial 11 finished with value: 16.219643909074463 and parameters: {'n_estimators': 228, 'max_depth': 5, 'min_samples_split': 7}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 10:59:04,029] Trial 12 finished with value: 15.731873468725896 and parameters: {'n_estimators': 285, 'max_depth': 16, 'min_samples_split': 2}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 10:59:10,687] Trial 13 finished with value: 15.733624855818517 and parameters: {'n_estimators': 101, 'max_depth': 9, 'min_samples_split': 8}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 10:59:24,986] Trial 14 finished with value: 15.750253780768745 and parameters: {'n_estimators': 157, 'max_depth': 14, 'min_samples_split': 5}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 10:59:47,984] Trial 15 finished with value: 15.780084275550358 and parameters: {'n_estimators': 224, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 11:00:02,990] Trial 16 finished with value: 15.73739586720272 and parameters: {'n_estimators': 258, 'max_depth': 8, 'min_samples_split': 4}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 11:00:34,284] Trial 17 finished with value: 15.776769581291964 and parameters: {'n_estimators': 300, 'max_depth': 20, 'min_samples_split': 17}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 11:00:45,661] Trial 18 finished with value: 15.788364571713107 and parameters: {'n_estimators': 208, 'max_depth': 7, 'min_samples_split': 9}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 11:00:59,602] Trial 19 finished with value: 15.715193157647075 and parameters: {'n_estimators': 168, 'max_depth': 12, 'min_samples_split': 6}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 11:01:12,326] Trial 20 finished with value: 15.733650792632575 and parameters: {'n_estimators': 125, 'max_depth': 15, 'min_samples_split': 2}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 11:01:31,343] Trial 21 finished with value: 15.71644170696997 and parameters: {'n_estimators': 267, 'max_depth': 10, 'min_samples_split': 4}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 11:01:49,703] Trial 22 finished with value: 15.709245640894748 and parameters: {'n_estimators': 252, 'max_depth': 10, 'min_samples_split': 6}. Best is trial 7 with value: 15.695130110672064.
# [I 2026-04-24 11:02:10,551] Trial 23 finished with value: 15.673553657357989 and parameters: {'n_estimators': 238, 'max_depth': 13, 'min_samples_split': 7}. Best is trial 23 with value: 15.673553657357989.
# [I 2026-04-24 11:02:29,608] Trial 24 finished with value: 15.687697492627118 and parameters: {'n_estimators': 221, 'max_depth': 13, 'min_samples_split': 9}. Best is trial 23 with value: 15.673553657357989.
# [I 2026-04-24 11:02:50,226] Trial 25 finished with value: 15.706662037482689 and parameters: {'n_estimators': 239, 'max_depth': 14, 'min_samples_split': 12}. Best is trial 23 with value: 15.673553657357989.
# [I 2026-04-24 11:03:11,344] Trial 26 finished with value: 15.767668714565973 and parameters: {'n_estimators': 207, 'max_depth': 18, 'min_samples_split': 9}. Best is trial 23 with value: 15.673553657357989.
# [I 2026-04-24 11:03:28,720] Trial 27 finished with value: 15.81748188413772 and parameters: {'n_estimators': 161, 'max_depth': 22, 'min_samples_split': 10}. Best is trial 23 with value: 15.673553657357989.
# [I 2026-04-24 11:03:43,835] Trial 28 finished with value: 15.70668222003416 and parameters: {'n_estimators': 183, 'max_depth': 12, 'min_samples_split': 7}. Best is trial 23 with value: 15.673553657357989.
# [I 2026-04-24 11:04:04,149] Trial 29 finished with value: 15.718467413632219 and parameters: {'n_estimators': 235, 'max_depth': 14, 'min_samples_split': 16}. Best is trial 23 with value: 15.673553657357989.
# =======================================================
#  [RandomForest (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 19.0238
#  NASA Score : 742.3220
# =======================================================
#   [XGBoost] Optuna 최적화 중...
# [I 2026-04-24 11:04:24,265] A new study created in memory with name: no-name-1fd391c1-68b8-4aef-b2cc-ede8ec0e821d
# [I 2026-04-24 11:04:35,929] Trial 0 finished with value: 16.216679141336147 and parameters: {'n_estimators': 287, 'max_depth': 10, 'learning_rate': 0.1205712628744377}. Best is trial 0 with value: 16.216679141336147.
# [I 2026-04-24 11:04:36,928] Trial 1 finished with value: 15.25594076540989 and parameters: {'n_estimators': 399, 'max_depth': 4, 'learning_rate': 0.01699897838270077}. Best is trial 1 with value: 15.25594076540989.
# [I 2026-04-24 11:04:40,712] Trial 2 finished with value: 15.964427982719258 and parameters: {'n_estimators': 129, 'max_depth': 9, 'learning_rate': 0.07725378389307355}. Best is trial 1 with value: 15.25594076540989.
# [I 2026-04-24 11:04:41,513] Trial 3 finished with value: 16.73865363865223 and parameters: {'n_estimators': 454, 'max_depth': 3, 'learning_rate': 0.2708160864249968}. Best is trial 1 with value: 15.25594076540989.
# [I 2026-04-24 11:04:42,780] Trial 4 finished with value: 15.228163296913419 and parameters: {'n_estimators': 517, 'max_depth': 4, 'learning_rate': 0.01855998084649059}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:04:43,453] Trial 5 finished with value: 15.60922641320671 and parameters: {'n_estimators': 191, 'max_depth': 5, 'learning_rate': 0.05958389350068958}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:04:44,421] Trial 6 finished with value: 15.862436203944801 and parameters: {'n_estimators': 316, 'max_depth': 5, 'learning_rate': 0.08012737503998542}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:04:44,988] Trial 7 finished with value: 15.331496805971797 and parameters: {'n_estimators': 169, 'max_depth': 5, 'learning_rate': 0.03476649150592621}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:04:53,104] Trial 8 finished with value: 15.847131010984192 and parameters: {'n_estimators': 328, 'max_depth': 9, 'learning_rate': 0.019721610970574007}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:04:56,002] Trial 9 finished with value: 15.586872916008673 and parameters: {'n_estimators': 357, 'max_depth': 7, 'learning_rate': 0.011711509955524094}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:00,305] Trial 10 finished with value: 15.764855055065574 and parameters: {'n_estimators': 590, 'max_depth': 7, 'learning_rate': 0.028758880048192027}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:01,198] Trial 11 finished with value: 15.434745511946566 and parameters: {'n_estimators': 515, 'max_depth': 3, 'learning_rate': 0.011407797829608162}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:02,187] Trial 12 finished with value: 15.24327264204914 and parameters: {'n_estimators': 439, 'max_depth': 4, 'learning_rate': 0.018178455267325335}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:04,378] Trial 13 finished with value: 15.763338768201796 and parameters: {'n_estimators': 497, 'max_depth': 6, 'learning_rate': 0.03357298176751253}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:05,613] Trial 14 finished with value: 15.286338660981023 and parameters: {'n_estimators': 566, 'max_depth': 4, 'learning_rate': 0.02024058816301111}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:06,569] Trial 15 finished with value: 15.35343847872903 and parameters: {'n_estimators': 433, 'max_depth': 4, 'learning_rate': 0.01027166617964368}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:08,780] Trial 16 finished with value: 15.790975402894043 and parameters: {'n_estimators': 512, 'max_depth': 6, 'learning_rate': 0.04246899194278214}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:09,245] Trial 17 finished with value: 15.413924404633553 and parameters: {'n_estimators': 261, 'max_depth': 3, 'learning_rate': 0.023392690295858172}. Best is trial 4 with value: 15.228163296913419.
# [I 2026-04-24 11:05:10,167] Trial 18 finished with value: 15.218590079530662 and parameters: {'n_estimators': 414, 'max_depth': 4, 'learning_rate': 0.01646603889196002}. Best is trial 18 with value: 15.218590079530662.
# [I 2026-04-24 11:05:15,603] Trial 19 finished with value: 15.756506650620711 and parameters: {'n_estimators': 380, 'max_depth': 8, 'learning_rate': 0.013998321249204585}. Best is trial 18 with value: 15.218590079530662.
# [I 2026-04-24 11:05:17,208] Trial 20 finished with value: 16.35041746020715 and parameters: {'n_estimators': 548, 'max_depth': 5, 'learning_rate': 0.1597843901181593}. Best is trial 18 with value: 15.218590079530662.
# [I 2026-04-24 11:05:18,191] Trial 21 finished with value: 15.209380036308751 and parameters: {'n_estimators': 441, 'max_depth': 4, 'learning_rate': 0.016374713808725447}. Best is trial 21 with value: 15.209380036308751.
# [I 2026-04-24 11:05:18,946] Trial 22 finished with value: 15.322265002589216 and parameters: {'n_estimators': 465, 'max_depth': 3, 'learning_rate': 0.025285448651923816}. Best is trial 21 with value: 15.209380036308751.
# [I 2026-04-24 11:05:19,849] Trial 23 finished with value: 15.230337505846421 and parameters: {'n_estimators': 408, 'max_depth': 4, 'learning_rate': 0.01467513742733727}. Best is trial 21 with value: 15.209380036308751.
# [I 2026-04-24 11:05:22,007] Trial 24 finished with value: 15.86440085466637 and parameters: {'n_estimators': 489, 'max_depth': 6, 'learning_rate': 0.044236216057795055}. Best is trial 21 with value: 15.209380036308751.
# [I 2026-04-24 11:05:23,687] Trial 25 finished with value: 15.354493398653597 and parameters: {'n_estimators': 529, 'max_depth': 5, 'learning_rate': 0.014499198072882911}. Best is trial 21 with value: 15.209380036308751.
# [I 2026-04-24 11:05:24,688] Trial 26 finished with value: 15.26666549838088 and parameters: {'n_estimators': 474, 'max_depth': 4, 'learning_rate': 0.02478844050177879}. Best is trial 21 with value: 15.209380036308751.
# [I 2026-04-24 11:05:25,366] Trial 27 finished with value: 15.313118809243779 and parameters: {'n_estimators': 418, 'max_depth': 3, 'learning_rate': 0.03326537232035192}. Best is trial 21 with value: 15.209380036308751.
# [I 2026-04-24 11:05:27,090] Trial 28 finished with value: 15.509099934752268 and parameters: {'n_estimators': 375, 'max_depth': 6, 'learning_rate': 0.01002298459911717}. Best is trial 21 with value: 15.209380036308751.
# [I 2026-04-24 11:05:27,847] Trial 29 finished with value: 16.095942849696726 and parameters: {'n_estimators': 248, 'max_depth': 5, 'learning_rate': 0.128621621271575}. Best is trial 21 with value: 15.209380036308751.
# =======================================================
#  [XGBoost (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 18.3804
#  NASA Score : 598.2326
# =======================================================
#   [LightGBM] Optuna 최적화 중...
# [I 2026-04-24 11:05:28,973] A new study created in memory with name: no-name-518fe9fc-39c2-4cf0-beb9-44f9e9293d00
# [I 2026-04-24 11:05:30,396] Trial 0 finished with value: 16.155833744240752 and parameters: {'n_estimators': 287, 'max_depth': 12, 'learning_rate': 0.1205712628744377, 'num_leaves': 128}. Best is trial 0 with value: 16.155833744240752.
# [I 2026-04-24 11:05:30,646] Trial 1 finished with value: 16.46319099212836 and parameters: {'n_estimators': 178, 'max_depth': 4, 'learning_rate': 0.012184186502221764, 'num_leaves': 176}. Best is trial 0 with value: 16.155833744240752.
# [I 2026-04-24 11:05:33,738] Trial 2 finished with value: 15.814614525725446 and parameters: {'n_estimators': 401, 'max_depth': 10, 'learning_rate': 0.010725209743171996, 'num_leaves': 195}. Best is trial 2 with value: 15.814614525725446.
# [I 2026-04-24 11:05:34,419] Trial 3 finished with value: 15.326514976168466 and parameters: {'n_estimators': 517, 'max_depth': 5, 'learning_rate': 0.01855998084649059, 'num_leaves': 53}. Best is trial 3 with value: 15.326514976168466.
# [I 2026-04-24 11:05:35,147] Trial 4 finished with value: 15.62549766868191 and parameters: {'n_estimators': 252, 'max_depth': 8, 'learning_rate': 0.04345454109729477, 'num_leaves': 72}. Best is trial 3 with value: 15.326514976168466.
# [I 2026-04-24 11:05:35,568] Trial 5 finished with value: 15.272207861779151 and parameters: {'n_estimators': 406, 'max_depth': 4, 'learning_rate': 0.027010527749605478, 'num_leaves': 86}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:37,284] Trial 6 finished with value: 15.635637930764034 and parameters: {'n_estimators': 328, 'max_depth': 10, 'learning_rate': 0.019721610970574007, 'num_leaves': 113}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:37,562] Trial 7 finished with value: 15.563511826484048 and parameters: {'n_estimators': 396, 'max_depth': 3, 'learning_rate': 0.07896186801026692, 'num_leaves': 50}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:38,453] Trial 8 finished with value: 16.856386917007022 and parameters: {'n_estimators': 132, 'max_depth': 12, 'learning_rate': 0.26690431824362526, 'num_leaves': 166}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:38,687] Trial 9 finished with value: 15.558107844161356 and parameters: {'n_estimators': 252, 'max_depth': 3, 'learning_rate': 0.1024932221692416, 'num_leaves': 99}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:39,389] Trial 10 finished with value: 15.59557656150701 and parameters: {'n_estimators': 578, 'max_depth': 6, 'learning_rate': 0.03550449468859506, 'num_leaves': 23}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:40,033] Trial 11 finished with value: 15.424608693821309 and parameters: {'n_estimators': 511, 'max_depth': 5, 'learning_rate': 0.02384080756773536, 'num_leaves': 70}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:40,624] Trial 12 finished with value: 15.385625208371112 and parameters: {'n_estimators': 473, 'max_depth': 6, 'learning_rate': 0.02082559172065853, 'num_leaves': 21}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:41,809] Trial 13 finished with value: 15.757760984407454 and parameters: {'n_estimators': 473, 'max_depth': 7, 'learning_rate': 0.03205809078417295, 'num_leaves': 78}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:42,556] Trial 14 finished with value: 15.358441486673113 and parameters: {'n_estimators': 587, 'max_depth': 5, 'learning_rate': 0.016283378515387005, 'num_leaves': 46}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:42,958] Trial 15 finished with value: 15.584492251689376 and parameters: {'n_estimators': 404, 'max_depth': 4, 'learning_rate': 0.05817353020682593, 'num_leaves': 137}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:44,464] Trial 16 finished with value: 15.67526201468861 and parameters: {'n_estimators': 506, 'max_depth': 8, 'learning_rate': 0.029491564140172923, 'num_leaves': 89}. Best is trial 5 with value: 15.272207861779151.
# [I 2026-04-24 11:05:45,077] Trial 17 finished with value: 15.246317850954432 and parameters: {'n_estimators': 430, 'max_depth': 5, 'learning_rate': 0.015401818885932124, 'num_leaves': 47}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:46,209] Trial 18 finished with value: 15.53036092424381 and parameters: {'n_estimators': 353, 'max_depth': 7, 'learning_rate': 0.013854597776925806, 'num_leaves': 111}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:46,597] Trial 19 finished with value: 15.541287698526597 and parameters: {'n_estimators': 414, 'max_depth': 4, 'learning_rate': 0.051244622204283934, 'num_leaves': 33}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:47,234] Trial 20 finished with value: 16.324609254103414 and parameters: {'n_estimators': 327, 'max_depth': 6, 'learning_rate': 0.18188215906458052, 'num_leaves': 57}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:47,918] Trial 21 finished with value: 15.293662671500122 and parameters: {'n_estimators': 534, 'max_depth': 5, 'learning_rate': 0.018651837921860284, 'num_leaves': 59}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:48,247] Trial 22 finished with value: 15.277967873723592 and parameters: {'n_estimators': 471, 'max_depth': 3, 'learning_rate': 0.026302941043371282, 'num_leaves': 88}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:48,564] Trial 23 finished with value: 15.291926590190714 and parameters: {'n_estimators': 442, 'max_depth': 3, 'learning_rate': 0.026143116295098474, 'num_leaves': 82}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:48,992] Trial 24 finished with value: 15.415547940082096 and parameters: {'n_estimators': 467, 'max_depth': 4, 'learning_rate': 0.03828911424845252, 'num_leaves': 97}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:49,299] Trial 25 finished with value: 15.796286640508214 and parameters: {'n_estimators': 371, 'max_depth': 3, 'learning_rate': 0.010458449355118436, 'num_leaves': 128}. Best is trial 17 with value: 15.246317850954432.
# [I 2026-04-24 11:05:49,732] Trial 26 finished with value: 15.200452876632479 and parameters: {'n_estimators': 458, 'max_depth': 4, 'learning_rate': 0.015259146747200466, 'num_leaves': 98}. Best is trial 26 with value: 15.200452876632479.
# [I 2026-04-24 11:05:50,639] Trial 27 finished with value: 15.406563818664946 and parameters: {'n_estimators': 439, 'max_depth': 6, 'learning_rate': 0.013902773119066696, 'num_leaves': 151}. Best is trial 26 with value: 15.200452876632479.
# [I 2026-04-24 11:05:51,139] Trial 28 finished with value: 15.22549066789506 and parameters: {'n_estimators': 549, 'max_depth': 4, 'learning_rate': 0.017146031895786944, 'num_leaves': 103}. Best is trial 26 with value: 15.200452876632479.
# [I 2026-04-24 11:05:53,975] Trial 29 finished with value: 15.647927672360842 and parameters: {'n_estimators': 552, 'max_depth': 10, 'learning_rate': 0.01543412546683848, 'num_leaves': 120}. Best is trial 26 with value: 15.200452876632479.
# =======================================================
#  [LightGBM (Optuna)] 모델 평가 결과
# -------------------------------------------------------
#  RMSE       : 18.3532
#  NASA Score : 611.9325
# =======================================================
